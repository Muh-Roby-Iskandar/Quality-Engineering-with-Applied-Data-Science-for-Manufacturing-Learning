# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =  pd.read_excel(r"C:\Users\Robyi\Documents\Latihan Minitab\salesdatavisualize.xlsx")

# %%
df.head()
# Out:
#         Date  Day    Month  Year  Customer_Age             Age_Group  \
# 0 2011-01-01    1  January  2011            33  Young Adults (25-34)
# 1 2011-01-01    1  January  2011            23           Youth (<25)
# 2 2011-01-01    1  January  2011            17           Youth (<25)
# 3 2011-01-01    1  January  2011            39        Adults (35-64)
# 4 2011-01-01    1  January  2011            42        Adults (35-64)
#
#   Customer_Gender        Country             State Product_Category  \
# 0               F         France           Yveline            Bikes
# 1               M      Australia          Victoria            Bikes
# 2               M         Canada  British Columbia            Bikes
# 3               M  United States        Washington            Bikes
# 4               M  United States        California            Bikes
#
#      Sub_Category                 Product  Order_Quantity  Unit_Cost  \
# ...

# %%
df.tail()
# Out:
#              Date  Day Month  Year  Customer_Age             Age_Group  \
# 112031 2016-07-31   31  July  2016            47        Adults (35-64)
# 112032 2016-07-31   31  July  2016            39        Adults (35-64)
# 112033 2016-07-31   31  July  2016            21           Youth (<25)
# 112034 2016-07-31   31  July  2016            31  Young Adults (25-34)
# 112035 2016-07-31   31  July  2016            34  Young Adults (25-34)
#
#        Customer_Gender         Country            State Product_Category  \
# 112031               F  United Kingdom          England         Clothing
# 112032               M   United States       California      Accessories
# 112033               F       Australia  New South Wales      Accessories
# 112034               M       Australia       Queensland      Accessories
# 112035               M       Australia  New South Wales      Accessories
#
#            Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# ...

# %%
df["State"]
# Out:
# 0                  Yveline
# 1                 Victoria
# 2         British Columbia
# 3               Washington
# 4               California
#                 ...
# 112031             England
# 112032          California
# 112033     New South Wales
# 112034          Queensland
# 112035     New South Wales
# Name: State, Length: 112036, dtype: object

# %%
df.State
# Out:
# 0                  Yveline
# 1                 Victoria
# 2         British Columbia
# 3               Washington
# 4               California
#                 ...
# 112031             England
# 112032          California
# 112033     New South Wales
# 112034          Queensland
# 112035     New South Wales
# Name: State, Length: 112036, dtype: object

# %%
df.loc[1]
# Out:
# Date                   2011-01-01 00:00:00
# Day                                      1
# Month                              January
# Year                                  2011
# Customer_Age                            23
# Age_Group                      Youth (<25)
# Customer_Gender                          M
# Country                          Australia
# State                             Victoria
# Product_Category                     Bikes
# Sub_Category                Mountain Bikes
# Product             Mountain-200 Black, 46
# Order_Quantity                           1
# Unit_Cost                             1252
# Unit_Price                            2295
# Profit                                 561
# Cost                                  1252
# Revenue                               1813
# Name: 1, dtype: object

# %%
df.loc[0]
# Out:
# Date                 2011-01-01 00:00:00
# Day                                    1
# Month                            January
# Year                                2011
# Customer_Age                          33
# Age_Group           Young Adults (25-34)
# Customer_Gender                        F
# Country                           France
# State                            Yveline
# Product_Category                   Bikes
# Sub_Category                  Road Bikes
# Product                 Road-150 Red, 48
# Order_Quantity                         2
# Unit_Cost                           2171
# Unit_Price                          3578
# Profit                              1097
# Cost                                4342
# Revenue                             5439
# Name: 0, dtype: object

# %%
df.iloc[3:9]
# Out:
#         Date  Day    Month  Year  Customer_Age             Age_Group  \
# 3 2011-01-01    1  January  2011            39        Adults (35-64)
# 4 2011-01-01    1  January  2011            42        Adults (35-64)
# 5 2011-01-02    2  January  2011            41        Adults (35-64)
# 6 2011-01-02    2  January  2011            40        Adults (35-64)
# 7 2011-01-02    2  January  2011            35        Adults (35-64)
# 8 2011-01-02    2  January  2011            32  Young Adults (25-34)
#
#   Customer_Gender         Country       State Product_Category Sub_Category  \
# 3               M   United States  Washington            Bikes   Road Bikes
# 4               M   United States  California            Bikes   Road Bikes
# 5               F       Australia  Queensland            Bikes   Road Bikes
# 6               M       Australia    Victoria            Bikes   Road Bikes
# 7               F   United States  California            Bikes   Road Bikes
# ...

# %%
df.iloc[1:6]
# Out:
#         Date  Day    Month  Year  Customer_Age       Age_Group  \
# 1 2011-01-01    1  January  2011            23     Youth (<25)
# 2 2011-01-01    1  January  2011            17     Youth (<25)
# 3 2011-01-01    1  January  2011            39  Adults (35-64)
# 4 2011-01-01    1  January  2011            42  Adults (35-64)
# 5 2011-01-02    2  January  2011            41  Adults (35-64)
#
#   Customer_Gender        Country             State Product_Category  \
# 1               M      Australia          Victoria            Bikes
# 2               M         Canada  British Columbia            Bikes
# 3               M  United States        Washington            Bikes
# 4               M  United States        California            Bikes
# 5               F      Australia        Queensland            Bikes
#
#      Sub_Category                 Product  Order_Quantity  Unit_Cost  \
# 1  Mountain Bikes  Mountain-200 Black, 46               1       1252
# ...

# %%
df['Year'] == 2012
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 112031    False
# 112032    False
# 112033    False
# 112034    False
# 112035    False
# Name: Year, Length: 112036, dtype: bool

# %%
df['Sub_Category'] == 'Mountain Bikes'
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 112031    False
# 112032    False
# 112033    False
# 112034    False
# 112035    False
# Name: Sub_Category, Length: 112036, dtype: bool

# %%
df['Australia'] = df['Country'] == 'Australia'
df['Australia'].head()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: Australia, dtype: bool

# %%
del df['Day']

# %%
df.head(2)
# Out:
#         Date    Month  Year  Customer_Age             Age_Group  \
# 0 2011-01-01  January  2011            33  Young Adults (25-34)
# 1 2011-01-01  January  2011            23           Youth (<25)
#
#   Customer_Gender    Country     State Product_Category    Sub_Category  \
# 0               F     France   Yveline            Bikes      Road Bikes
# 1               M  Australia  Victoria            Bikes  Mountain Bikes
#
#                   Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# 0        Road-150 Red, 48               2       2171        3578    1097
# 1  Mountain-200 Black, 46               1       1252        2295     561
#
#    Cost  Revenue  Australia
# 0  4342     5439      False
# 1  1252     1813       True

# %%
del df['Month']

# %%
del df['Year']

# %%
df.head(2)
# Out:
#         Date  Customer_Age             Age_Group Customer_Gender    Country  \
# 0 2011-01-01            33  Young Adults (25-34)               F     France
# 1 2011-01-01            23           Youth (<25)               M  Australia
#
#       State Product_Category    Sub_Category                 Product  \
# 0   Yveline            Bikes      Road Bikes        Road-150 Red, 48
# 1  Victoria            Bikes  Mountain Bikes  Mountain-200 Black, 46
#
#    Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  Revenue  Australia
# 0               2       2171        3578    1097  4342     5439      False
# 1               1       1252        2295     561  1252     1813       True

# %%
df1 = df.to_numpy()

# %%
df1
# Out:
# array([[Timestamp('2011-01-01 00:00:00'), 33, 'Young Adults (25-34)',
#         ..., 4342, 5439, False],
#        [Timestamp('2011-01-01 00:00:00'), 23, 'Youth (<25)', ..., 1252,
#         1813, True],
#        [Timestamp('2011-01-01 00:00:00'), 17, 'Youth (<25)', ..., 1519,
#         2419, False],
#        ...,
#        [Timestamp('2016-07-31 00:00:00'), 21, 'Youth (<25)', ..., 63,
#         144, True],
#        [Timestamp('2016-07-31 00:00:00'), 31, 'Young Adults (25-34)',
#         ..., 19, 64, True],
#        [Timestamp('2016-07-31 00:00:00'), 34, 'Young Adults (25-34)',
#         ..., 16, 35, True]], dtype=object)

# %%
df.columns
# Out:
# Index(['Date', 'Customer_Age', 'Age_Group', 'Customer_Gender', 'Country',
#        'State', 'Product_Category', 'Sub_Category', 'Product',
#        'Order_Quantity', 'Unit_Cost', 'Unit_Price', 'Profit', 'Cost',
#        'Revenue', 'Australia'],
#       dtype='object')

# %%
df.index.name = 'ID'

# %%
'Date' in df.columns
# Out:
# True

# %%
'Day' in df.columns
# Out:
# False

# %%
100 in df.index
# Out:
# True

# %%
2000000 in df.index
# Out:
# False

# %%
df.loc[[1, 10, 100], ['State','Profit']]
# Out:
#                  State  Profit
# ID
# 1             Victoria     561
# 10             England     961
# 100  Seine Saint Denis    1793

# %%
df.drop(1)
# Out:
#              Date  Customer_Age             Age_Group Customer_Gender  \
# ID
# 0      2011-01-01            33  Young Adults (25-34)               F
# 2      2011-01-01            17           Youth (<25)               M
# 3      2011-01-01            39        Adults (35-64)               M
# 4      2011-01-01            42        Adults (35-64)               M
# 5      2011-01-02            41        Adults (35-64)               F
# ...           ...           ...                   ...             ...
# 112031 2016-07-31            47        Adults (35-64)               F
# 112032 2016-07-31            39        Adults (35-64)               M
# 112033 2016-07-31            21           Youth (<25)               F
# 112034 2016-07-31            31  Young Adults (25-34)               M
# 112035 2016-07-31            34  Young Adults (25-34)               M
#
#                Country             State Product_Category     Sub_Category  \
# ID
# ...

# %%
df.drop(1, inplace = True)

# %%
df.drop([5,10,20,22], inplace =True)

# %%
df
# Out:
#              Date  Customer_Age             Age_Group Customer_Gender  \
# ID
# 0      2011-01-01            33  Young Adults (25-34)               F
# 2      2011-01-01            17           Youth (<25)               M
# 3      2011-01-01            39        Adults (35-64)               M
# 4      2011-01-01            42        Adults (35-64)               M
# 6      2011-01-02            40        Adults (35-64)               M
# ...           ...           ...                   ...             ...
# 112031 2016-07-31            47        Adults (35-64)               F
# 112032 2016-07-31            39        Adults (35-64)               M
# 112033 2016-07-31            21           Youth (<25)               F
# 112034 2016-07-31            31  Young Adults (25-34)               M
# 112035 2016-07-31            34  Young Adults (25-34)               M
#
#                Country             State Product_Category     Sub_Category  \
# ID
# ...

# %%
df.drop(index=[3,4], inplace = True)

# %%
df.head()
# Out:
#          Date  Customer_Age             Age_Group Customer_Gender  \
# ID
# 0  2011-01-01            33  Young Adults (25-34)               F
# 2  2011-01-01            17           Youth (<25)               M
# 6  2011-01-02            40        Adults (35-64)               M
# 7  2011-01-02            35        Adults (35-64)               F
# 8  2011-01-02            32  Young Adults (25-34)               M
#
#            Country             State Product_Category Sub_Category  \
# ID
# 0           France           Yveline            Bikes   Road Bikes
# 2           Canada  British Columbia            Bikes   Road Bikes
# 6        Australia          Victoria            Bikes   Road Bikes
# 7    United States        California            Bikes   Road Bikes
# 8   United Kingdom           England            Bikes   Road Bikes
#
#                   Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  \
# ID
# 0        Road-150 Red, 48               2       2171        3578    1097
# ...

# %%
df.drop(columns = ['Age_Group'], inplace = True)

# %%
df.head()
# Out:
#          Date  Customer_Age Customer_Gender         Country             State  \
# ID
# 0  2011-01-01            33               F          France           Yveline
# 2  2011-01-01            17               M          Canada  British Columbia
# 6  2011-01-02            40               M       Australia          Victoria
# 7  2011-01-02            35               F   United States        California
# 8  2011-01-02            32               M  United Kingdom           England
#
#    Product_Category Sub_Category                Product  Order_Quantity  \
# ID
# 0             Bikes   Road Bikes       Road-150 Red, 48               2
# 2             Bikes   Road Bikes       Road-250 Red, 44               1
# 6             Bikes   Road Bikes  Road-550-W Yellow, 40               4
# 7             Bikes   Road Bikes  Road-550-W Yellow, 48               1
# 8             Bikes   Road Bikes  Road-550-W Yellow, 38               1
#
# ...

# %%
df.iloc[100:105]
# Out:
#           Date  Customer_Age Customer_Gender         Country       State  \
# ID
# 107 2011-01-18            18               M       Australia    Victoria
# 108 2011-01-19            39               F   United States      Oregon
# 109 2011-01-19            41               F       Australia  Queensland
# 110 2011-01-19            35               F   United States  Washington
# 111 2011-01-19            36               F  United Kingdom     England
#
#     Product_Category Sub_Category                Product  Order_Quantity  \
# ID
# 107            Bikes   Road Bikes     Road-750 Black, 52               1
# 108            Bikes   Road Bikes  Road-550-W Yellow, 48               3
# 109            Bikes   Road Bikes       Road-250 Red, 58               1
# 110            Bikes   Road Bikes       Road-150 Red, 56               1
# 111            Bikes   Road Bikes  Road-350-W Yellow, 48               2
#
#      Unit_Cost  Unit_Price  Profit  Cost  Revenue  Australia
# ID
# ...

# %%
df['Customer_Gender']
# Out:
# ID
# 0         F
# 2         M
# 6         M
# 7         F
# 8         M
#          ..
# 112031    F
# 112032    M
# 112033    F
# 112034    M
# 112035    M
# Name: Customer_Gender, Length: 112029, dtype: object

# %%
df2 = df[['Date','State','Profit','Order_Quantity']]

# %%
df2.head()
# Out:
#          Date             State  Profit  Order_Quantity
# ID
# 0  2011-01-01           Yveline    1097               2
# 2  2011-01-01  British Columbia     900               1
# 6  2011-01-02          Victoria     687               4
# 7  2011-01-02        California     385               1
# 8  2011-01-02           England     362               1

# %%
df[:5]
# Out:
#          Date  Customer_Age Customer_Gender         Country             State  \
# ID
# 0  2011-01-01            33               F          France           Yveline
# 2  2011-01-01            17               M          Canada  British Columbia
# 6  2011-01-02            40               M       Australia          Victoria
# 7  2011-01-02            35               F   United States        California
# 8  2011-01-02            32               M  United Kingdom           England
#
#    Product_Category Sub_Category                Product  Order_Quantity  \
# ID
# 0             Bikes   Road Bikes       Road-150 Red, 48               2
# 2             Bikes   Road Bikes       Road-250 Red, 44               1
# 6             Bikes   Road Bikes  Road-550-W Yellow, 40               4
# 7             Bikes   Road Bikes  Road-550-W Yellow, 48               1
# 8             Bikes   Road Bikes  Road-550-W Yellow, 38               1
#
# ...

# %%
df[df['Country'] == 'France']
# Out:
#              Date  Customer_Age Customer_Gender Country            State  \
# ID
# 0      2011-01-01            33               F  France          Yveline
# 19     2011-01-04            33               F  France             Nord
# 51     2011-01-10            33               F  France             Nord
# 61     2011-01-12            33               F  France  Garonne (Haute)
# 66     2011-01-12            30               M  France    Seine (Paris)
# ...           ...           ...             ...     ...              ...
# 111833 2016-07-28            19               F  France  Garonne (Haute)
# 111834 2016-07-28            19               F  France  Garonne (Haute)
# 111836 2016-07-28            23               F  France     Val de Marne
# 111837 2016-07-28            19               F  France  Garonne (Haute)
# 111894 2016-07-29            32               F  France   Hauts de Seine
#
#        Product_Category     Sub_Category                          Product  \
# ID
# ...

# %%
df[df['Profit'] >= 2000]
# Out:
#              Date  Customer_Age Customer_Gender         Country  \
# ID
# 9      2011-01-03            39               F   United States
# 13     2011-01-03            28               M  United Kingdom
# 17     2011-01-04            28               M  United Kingdom
# 25     2011-01-06            44               F   United States
# 36     2011-01-08            35               M   United States
# ...           ...           ...             ...             ...
# 109843 2016-06-29            26               F  United Kingdom
# 109895 2016-06-30            32               M       Australia
# 109901 2016-06-30            43               F          Canada
# 109972 2016-06-30            35               M   United States
# 109983 2016-06-30            37               F   United States
#
#                    State Product_Category    Sub_Category  \
# ID
# 9             California            Bikes      Road Bikes
# 13               England            Bikes  Mountain Bikes
# ...

# %%
df['Order_Quantity'] < 5
# Out:
# ID
# 0          True
# 2          True
# 6          True
# 7          True
# 8          True
#           ...
# 112031    False
# 112032    False
# 112033     True
# 112034    False
# 112035    False
# Name: Order_Quantity, Length: 112029, dtype: bool

# %%
df3 = df[df['Order_Quantity'] < 5] = 0
# Out:
# C:\Users\Robyi\AppData\Local\Temp\ipykernel_10172\1295404603.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   df3 = df[df['Order_Quantity'] < 5] = 0
# C:\Users\Robyi\AppData\Local\Temp\ipykernel_10172\1295404603.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df3 = df[df['Order_Quantity'] < 5] = 0

# %%
df.head()
# Out:
#    Date  Customer_Age Customer_Gender Country State Product_Category  \
# ID
# 0     0             0               0       0     0                0
# 2     0             0               0       0     0                0
# 6     0             0               0       0     0                0
# 7     0             0               0       0     0                0
# 8     0             0               0       0     0                0
#
#    Sub_Category Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ID
# 0             0       0               0          0           0       0     0
# 2             0       0               0          0           0       0     0
# 6             0       0               0          0           0       0     0
# 7             0       0               0          0           0       0     0
# 8             0       0               0          0           0       0     0
#
#     Revenue Australia
# ID
# 0         0         0
# 2         0         0
# ...
