# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df =  pd.read_excel(r"C:\Users\Robyi\Documents\Latihan Minitab\salesdatavisualize.xlsx")

# %%
df.head()
# Out:
#         Date  Day    Month  Year  Customer_Age             Age_Group  \
# 0 2011-01-01    1  January  2011            33  Young Adults (25-34)
# 1 2011-01-01    1  January  2011            23           Youth (<25)
# 2 2011-01-01    1  January  2011            17           Youth (<25)
# 3 2011-01-01    1  January  2011            39        Adults (35-64)
# 4 2011-01-01    1  January  2011            42        Adults (35-64)
#
#   Customer_Gender        Country             State Product_Category  \
# 0               F         France           Yveline            Bikes
# 1               M      Australia          Victoria            Bikes
# 2               M         Canada  British Columbia            Bikes
# 3               M  United States        Washington            Bikes
# 4               M  United States        California            Bikes
#
#      Sub_Category                 Product  Order_Quantity  Unit_Cost  \
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of              Date  Day    Month  Year  Customer_Age             Age_Group  \
# 0      2011-01-01    1  January  2011            33  Young Adults (25-34)
# 1      2011-01-01    1  January  2011            23           Youth (<25)
# 2      2011-01-01    1  January  2011            17           Youth (<25)
# 3      2011-01-01    1  January  2011            39        Adults (35-64)
# 4      2011-01-01    1  January  2011            42        Adults (35-64)
# ...           ...  ...      ...   ...           ...                   ...
# 112031 2016-07-31   31     July  2016            47        Adults (35-64)
# 112032 2016-07-31   31     July  2016            39        Adults (35-64)
# 112033 2016-07-31   31     July  2016            21           Youth (<25)
# 112034 2016-07-31   31     July  2016            31  Young Adults (25-34)
# 112035 2016-07-31   31     July  2016            34  Young Adults (25-34)
#
# ...

# %%
df.loc[[10,20]]
# Out:
#          Date  Day    Month  Year  Customer_Age       Age_Group  \
# 10 2011-01-03    3  January  2011            38  Adults (35-64)
# 20 2011-01-04    4  January  2011            36  Adults (35-64)
#
#    Customer_Gender         Country       State Product_Category  \
# 10               M  United Kingdom     England            Bikes
# 20               F   United States  California            Bikes
#
#       Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# 10  Mountain Bikes  Mountain-200 Silver, 42               1       1266
# 20      Road Bikes         Road-650 Red, 62               2        487
#
#     Unit_Price  Profit  Cost  Revenue
# 10        2320     961  1266     2227
# 20         783     561   974     1535

# %%
df.loc[10, ['State','Profit']]
# Out:
# State     England
# Profit        961
# Name: 10, dtype: object

# %%
df.iloc[[10,20]]
# Out:
#          Date  Day    Month  Year  Customer_Age       Age_Group  \
# 10 2011-01-03    3  January  2011            38  Adults (35-64)
# 20 2011-01-04    4  January  2011            36  Adults (35-64)
#
#    Customer_Gender         Country       State Product_Category  \
# 10               M  United Kingdom     England            Bikes
# 20               F   United States  California            Bikes
#
#       Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# 10  Mountain Bikes  Mountain-200 Silver, 42               1       1266
# 20      Road Bikes         Road-650 Red, 62               2        487
#
#     Unit_Price  Profit  Cost  Revenue
# 10        2320     961  1266     2227
# 20         783     561   974     1535

# %%
df.iloc[10,[3,4,5]]
# Out:
# Year                      2011
# Customer_Age                38
# Age_Group       Adults (35-64)
# Name: 10, dtype: object

# %%
df.iloc[0,[0]]
# Out:
# Date    2011-01-01 00:00:00
# Name: 0, dtype: object

# %%
df.loc[:5,'State']
# Out:
# 0             Yveline
# 1            Victoria
# 2    British Columbia
# 3          Washington
# 4          California
# 5          Queensland
# Name: State, dtype: object

# %%
df.loc[210:215, ['State','Profit']]
# Out:
#                State  Profit
# 210  South Australia      99
# 211       Washington     731
# 212          England    1059
# 213          England    2528
# 214  New South Wales    1587
# 215           Oregon    3014

# %%
df.loc[df.Profit >5000].head()
# Out:
#           Date  Day    Month  Year  Customer_Age             Age_Group  \
# 9   2011-01-03    3  January  2011            39        Adults (35-64)
# 83  2011-01-15   15  January  2011            72         Seniors (64+)
# 98  2011-01-17   17  January  2011            44        Adults (35-64)
# 99  2011-01-17   17  January  2011            30  Young Adults (25-34)
# 182 2011-01-31   31  January  2011            61        Adults (35-64)
#
#     Customer_Gender        Country       State Product_Category  \
# 9                 F  United States  California            Bikes
# 83                F  United States  California            Bikes
# 98                F  United States  California            Bikes
# 99                M  United States  California            Bikes
# 182               F  United States  California            Bikes
#
#        Sub_Category                 Product  Order_Quantity  Unit_Cost  \
# 9        Road Bikes        Road-150 Red, 48               4       2171
# ...

# %%
df[:3]
# Out:
#         Date  Day    Month  Year  Customer_Age             Age_Group  \
# 0 2011-01-01    1  January  2011            33  Young Adults (25-34)
# 1 2011-01-01    1  January  2011            23           Youth (<25)
# 2 2011-01-01    1  January  2011            17           Youth (<25)
#
#   Customer_Gender    Country             State Product_Category  \
# 0               F     France           Yveline            Bikes
# 1               M  Australia          Victoria            Bikes
# 2               M     Canada  British Columbia            Bikes
#
#      Sub_Category                 Product  Order_Quantity  Unit_Cost  \
# 0      Road Bikes        Road-150 Red, 48               2       2171
# 1  Mountain Bikes  Mountain-200 Black, 46               1       1252
# 2      Road Bikes        Road-250 Red, 44               1       1519
#
#    Unit_Price  Profit  Cost  Revenue
# 0        3578    1097  4342     5439
# 1        2295     561  1252     1813
# ...

# %%
df[112031:]
# Out:
#              Date  Day Month  Year  Customer_Age             Age_Group  \
# 112031 2016-07-31   31  July  2016            47        Adults (35-64)
# 112032 2016-07-31   31  July  2016            39        Adults (35-64)
# 112033 2016-07-31   31  July  2016            21           Youth (<25)
# 112034 2016-07-31   31  July  2016            31  Young Adults (25-34)
# 112035 2016-07-31   31  July  2016            34  Young Adults (25-34)
#
#        Customer_Gender         Country            State Product_Category  \
# 112031               F  United Kingdom          England         Clothing
# 112032               M   United States       California      Accessories
# 112033               F       Australia  New South Wales      Accessories
# 112034               M       Australia       Queensland      Accessories
# 112035               M       Australia  New South Wales      Accessories
#
#            Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# ...

# %%
df['Gross'] = df['Profit'] + df['Revenue']

# %%
df.head()
# Out:
#         Date  Day    Month  Year  Customer_Age             Age_Group  \
# 0 2011-01-01    1  January  2011            33  Young Adults (25-34)
# 1 2011-01-01    1  January  2011            23           Youth (<25)
# 2 2011-01-01    1  January  2011            17           Youth (<25)
# 3 2011-01-01    1  January  2011            39        Adults (35-64)
# 4 2011-01-01    1  January  2011            42        Adults (35-64)
#
#   Customer_Gender        Country             State Product_Category  \
# 0               F         France           Yveline            Bikes
# 1               M      Australia          Victoria            Bikes
# 2               M         Canada  British Columbia            Bikes
# 3               M  United States        Washington            Bikes
# 4               M  United States        California            Bikes
#
#      Sub_Category                 Product  Order_Quantity  Unit_Cost  \
# ...

# %%
df['Gross'] > 6000
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 112031    False
# 112032    False
# 112033    False
# 112034    False
# 112035    False
# Name: Gross, Length: 112036, dtype: bool

# %%
df.sort_index(ascending = False).head()
# Out:
#              Date  Day Month  Year  Customer_Age             Age_Group  \
# 112035 2016-07-31   31  July  2016            34  Young Adults (25-34)
# 112034 2016-07-31   31  July  2016            31  Young Adults (25-34)
# 112033 2016-07-31   31  July  2016            21           Youth (<25)
# 112032 2016-07-31   31  July  2016            39        Adults (35-64)
# 112031 2016-07-31   31  July  2016            47        Adults (35-64)
#
#        Customer_Gender         Country            State Product_Category  \
# 112035               M       Australia  New South Wales      Accessories
# 112034               M       Australia       Queensland      Accessories
# 112033               F       Australia  New South Wales      Accessories
# 112032               M   United States       California      Accessories
# 112031               F  United Kingdom          England         Clothing
#
#            Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# ...

# %%
df.sort_index(axis = 'columns').head()
# Out:
#               Age_Group  Cost        Country  Customer_Age Customer_Gender  \
# 0  Young Adults (25-34)  4342         France            33               F
# 1           Youth (<25)  1252      Australia            23               M
# 2           Youth (<25)  1519         Canada            17               M
# 3        Adults (35-64)  2139  United States            39               M
# 4        Adults (35-64)   344  United States            42               M
#
#         Date  Day  Gross    Month  Order_Quantity                 Product  \
# 0 2011-01-01    1   6536  January               2        Road-150 Red, 48
# 1 2011-01-01    1   2374  January               1  Mountain-200 Black, 46
# 2 2011-01-01    1   3319  January               1        Road-250 Red, 44
# 3 2011-01-01    1   3103  January               3   Road-550-W Yellow, 38
# 4 2011-01-01    1    714  January               1      Road-750 Black, 44
#
# ...

# %%
df.sort_index(axis = 'columns', ascending = False).head()
# Out:
#    Year  Unit_Price  Unit_Cost    Sub_Category             State  Revenue  \
# 0  2011        3578       2171      Road Bikes           Yveline     5439
# 1  2011        2295       1252  Mountain Bikes          Victoria     1813
# 2  2011        2443       1519      Road Bikes  British Columbia     2419
# 3  2011        1120        713      Road Bikes        Washington     2621
# 4  2011         540        344      Road Bikes        California      529
#
#    Profit Product_Category                 Product  Order_Quantity    Month  \
# 0    1097            Bikes        Road-150 Red, 48               2  January
# 1     561            Bikes  Mountain-200 Black, 46               1  January
# 2     900            Bikes        Road-250 Red, 44               1  January
# 3     482            Bikes   Road-550-W Yellow, 38               3  January
# 4     185            Bikes      Road-750 Black, 44               1  January
#
# ...

# %%
df['Profit'].sort_values().head()
# Out:
# 80493   -30
# 27229   -29
# 70765   -25
# 17316   -25
# 8025    -24
# Name: Profit, dtype: int64

# %%
df['Cost'].sort_values(ascending = False).head()
# Out:
# 61441    42978
# 8131     40014
# 530       8684
# 99        8684
# 1355      8684
# Name: Cost, dtype: int64

# %%
df['State'].sort_values().head()
# Out:
# 22152     Alabama
# 110789    Alabama
# 57449     Alabama
# 75513     Alabama
# 18560     Alberta
# Name: State, dtype: object

# %%
df['Cost'].sort_values(na_position = "first")
# Out:
# 89600         1
# 19075         1
# 19071         1
# 76673         1
# 101564        1
#           ...
# 624        8684
# 263        8684
# 2160       8684
# 8131      40014
# 61441     42978
# Name: Cost, Length: 112036, dtype: int64

# %%
df['Order_Quantity'].rank()
# Out:
# 0         26202.0
# 1         11199.0
# 2         11199.0
# 3         32560.0
# 4         11199.0
#            ...
# 112031    86359.0
# 112032    46061.5
# 112033    32560.0
# 112034    80730.5
# 112035    48973.0
# Name: Order_Quantity, Length: 112036, dtype: float64

# %%
df['Order_Quantity'].rank(method = 'first')
# Out:
# 0         22398.0
# 1             1.0
# 2             2.0
# 3         30007.0
# 4             3.0
#            ...
# 112031    87736.0
# 112032    47542.0
# 112033    35113.0
# 112034    82133.0
# 112035    50403.0
# Name: Order_Quantity, Length: 112036, dtype: float64

# %%
df['Order_Quantity'].rank(ascending = False)
# Out:
# 0          85835.0
# 1         100838.0
# 2         100838.0
# 3          79477.0
# 4         100838.0
#             ...
# 112031     25678.0
# 112032     65975.5
# 112033     79477.0
# 112034     31306.5
# 112035     63064.0
# Name: Order_Quantity, Length: 112036, dtype: float64

# %%
df.index.is_unique
# Out:
# True

# %%
df[['Profit','Cost','Revenue']].sum()
# Out:
# Profit     32046239
# Cost       52780533
# Revenue    84826772
# dtype: int64

# %%
tes1 = df[df['Country'] == 'Canada']['Profit'].sum()
print(tes1)
# Out:
# 3702019

# %%
tes2 = df[df['Country'] == 'Australia']['Order_Quantity'].mean()
print(tes2)
# Out:
# 11.00551904280418

# %%
tes3 = df.groupby('Country')['Cost'].sum()
print(tes3)
# Out:
# Country
# Australia         14455873
# Canada             4204163
# France             5542663
# Germany            5606733
# United Kingdom     6191641
# United States     16779460
# Name: Cost, dtype: int64

# %%
tes4 = df.groupby('Customer_Gender')['Gross'].sum()
tes5 = tes4.sort_values(ascending = False)
print(tes5)
# Out:
# Customer_Gender
# M    59536503
# F    57336508
# Name: Gross, dtype: int64

# %%
df['Product'].value_counts()
# Out:
# Product
# Water Bottle - 30 oz.      10641
# Patch Kit/8 Patches        10256
# Mountain Tire Tube          6688
# AWC Logo Cap                4358
# Sport-100 Helmet, Red       4218
#                            ...
# Mountain-100 Silver, 48       58
# Mountain-100 Silver, 42       54
# Mountain-500 Silver, 48       40
# Road-650 Red, 52              32
# Mountain-500 Black, 52        22
# Name: count, Length: 130, dtype: int64

# %%
df['Product'].value_counts().sort_values(ascending =False).head()
# Out:
# Product
# Water Bottle - 30 oz.    10641
# Patch Kit/8 Patches      10256
# Mountain Tire Tube        6688
# AWC Logo Cap              4358
# Sport-100 Helmet, Red     4218
# Name: count, dtype: int64

# %%
tes6 = df['Country'].duplicated().sum()
print(tes6)
# Out:
# 112030

# %%
tes7= df[df.isnull().any(axis = 1)]
print(tes7)
# Out:
# Empty DataFrame
# Columns: [Date, Day, Month, Year, Customer_Age, Age_Group, Customer_Gender, Country, State, Product_Category, Sub_Category, Product, Order_Quantity, Unit_Cost, Unit_Price, Profit, Cost, Revenue, Gross]
# Index: []

# %%
tes8 = df[df['Country'] == 'Canada']['Cost'].max()
print(tes8)
# Out:
# 8684

# %%
df.loc[df['Country'] == 'Germany','Cost'].iloc[0]
# Out:
# 1083

# %%
df.loc[df['Product_Category'] == 'Bikes','Profit'].iloc[0]
# Out:
# 1097

# %%
df[df['Country'] == 'United States'][['Country','Profit','Cost']].head()
# Out:
#           Country  Profit  Cost
# 3   United States     482  2139
# 4   United States     185   344
# 7   United States     385   713
# 9   United States    5342  8684
# 12  United States    1008  1266

# %%
df[df['Country'] == 'United States'][['Country','Profit','Cost','Product']].head()
# Out:
#           Country  Profit  Cost                  Product
# 3   United States     482  2139    Road-550-W Yellow, 38
# 4   United States     185   344       Road-750 Black, 44
# 7   United States     385   713    Road-550-W Yellow, 48
# 9   United States    5342  8684         Road-150 Red, 48
# 12  United States    1008  1266  Mountain-200 Silver, 42

# %%
df[df['Sub_Category'] == 'Bike Stands'].head()
# Out:
#            Date  Day   Month  Year  Customer_Age             Age_Group  \
# 7079 2013-07-01    1    July  2013            37        Adults (35-64)
# 7956 2013-07-20   20    July  2013            34  Young Adults (25-34)
# 8011 2013-07-22   22    July  2013            18           Youth (<25)
# 8102 2013-07-24   24    July  2013            44        Adults (35-64)
# 8465 2013-08-01    1  August  2013            34  Young Adults (25-34)
#
#      Customer_Gender        Country            State Product_Category  \
# 7079               M         France             Nord      Accessories
# 7956               F  United States       California      Accessories
# 8011               F  United States       California      Accessories
# 8102               F      Australia       Queensland      Accessories
# 8465               M      Australia  New South Wales      Accessories
#
#      Sub_Category                 Product  Order_Quantity  Unit_Cost  \
# ...

# %%
df[df['Customer_Age'] >= 50][['Product','Country','Gross']]
# Out:
#                            Product        Country  Gross
# Date
# 2011-01-05      Road-650 Black, 60         Canada   3191
# 2011-01-11        Road-150 Red, 52  United States   9684
# 2011-01-14   Road-550-W Yellow, 42      Australia   3505
# 2011-01-15  Mountain-100 Black, 48  United States  18868
# 2011-01-16      Road-250 Black, 58      Australia   2695
# ...                            ...            ...    ...
# 2016-07-31  Sport-100 Helmet, Blue  United States   1668
# 2016-07-31   Water Bottle - 30 oz.         Canada     48
# 2016-07-31   Water Bottle - 30 oz.         Canada    102
# 2016-07-31         Classic Vest, S         Canada   1130
# 2016-07-31         Racing Socks, M        Germany    247
#
# [14668 rows x 3 columns]

# %%
df[df['Sub_Category'] == 'Bike Stands'][['Customer_Gender']].head()
# Out:
#      Customer_Gender
# 7079               M
# 7956               F
# 8011               F
# 8102               F
# 8465               M

# %%
df[df['Profit'] > 1000 ][['Country']].head()
# Out:
#            Country
# 0           France
# 5        Australia
# 9    United States
# 12   United States
# 13  United Kingdom

# %%
df[df['Profit'] > 500 ][['Country','Sub_Category','Date']].head()
# Out:
#      Country    Sub_Category       Date
# 0     France      Road Bikes 2011-01-01
# 1  Australia  Mountain Bikes 2011-01-01
# 2     Canada      Road Bikes 2011-01-01
# 5  Australia      Road Bikes 2011-01-02
# 6  Australia      Road Bikes 2011-01-02

# %%
df[df['Order_Quantity'] < 3 ][['Country','Sub_Category','Unit_Cost']].head()
# Out:
#          Country    Sub_Category  Unit_Cost
# 0         France      Road Bikes       2171
# 1      Australia  Mountain Bikes       1252
# 2         Canada      Road Bikes       1519
# 4  United States      Road Bikes        344
# 7  United States      Road Bikes        713

# %%
tesdata1 = df.groupby('Country')[['Cost','Profit','Revenue']].mean()
tesdata1
# Out:
#                       Cost      Profit     Revenue
# Country
# Australia       609.027342  283.978851  893.006193
# Canada          299.719327  263.920938  563.640265
# France          507.569872  263.011172  770.581044
# Germany         508.454974  303.798948  812.253922
# United Kingdom  459.116195  325.076895  784.193089
# United States   432.014933  283.152369  715.167302

# %%
tesdata2 = df.groupby('Product')[['Cost','Profit','Revenue']].max()
tesdata2.head()
# Out:
#                         Cost  Profit  Revenue
# Product
# AWC Logo Cap             224      61      285
# All-Purpose Bike Stand   708    1083     1732
# Bike Wash - Dissolver     96     157      253
# Classic Vest, L          744    1181     1905
# Classic Vest, M          744    1181     1901

# %%
tesdata3 = df['Product_Category'].value_counts()
tesdata3.head()
# Out:
# Product_Category
# Accessories    69312
# Bikes          25794
# Clothing       16930
# Name: count, dtype: int64

# %%
df['Order_Quantity'].mean()
# Out:
# 11.904253989788996

# %%
df['Customer_Age'].max()
# Out:
# 87

# %%
df['Customer_Age'].min()
# Out:
# 17

# %%
df.describe()
# Out:
#                                 Date            Day           Year  \
# count                         112036  112036.000000  112036.000000
# mean   2014-11-23 05:22:32.008282624      15.665607    2014.400925
# min              2011-01-01 00:00:00       1.000000    2011.000000
# 25%              2013-12-22 00:00:00       8.000000    2013.000000
# 50%              2014-06-27 00:00:00      16.000000    2014.000000
# 75%              2016-01-09 00:00:00      23.000000    2016.000000
# max              2016-07-31 00:00:00      31.000000    2016.000000
# std                              NaN       8.781485       1.273327
#
#         Customer_Age  Order_Quantity      Unit_Cost     Unit_Price  \
# count  112036.000000   112036.000000  112036.000000  112036.000000
# mean       35.919508       11.904254     267.819603     453.850628
# min        17.000000        1.000000       1.000000       2.000000
# 25%        28.000000        2.000000       2.000000       5.000000
# ...

# %%
df.idxmax()
# Out:
# Date                111954
# Day                    181
# Month                 1722
# Year                 82908
# Customer_Age         36380
# Age_Group                1
# Customer_Gender          1
# Country                  3
# State                    0
# Product_Category      7064
# Sub_Category          7238
# Product               8468
# Order_Quantity       60539
# Unit_Cost                0
# Unit_Price               0
# Profit               61441
# Cost                 61441
# Revenue              61441
# Gross                61441
# dtype: int64

# %%
df.nunique()
# Out:
# Date                1884
# Day                   31
# Month                 12
# Year                   6
# Customer_Age          70
# Age_Group              4
# Customer_Gender        2
# Country                6
# State                 53
# Product_Category       3
# Sub_Category          17
# Product              130
# Order_Quantity        32
# Unit_Cost             34
# Unit_Price            36
# Profit              1256
# Cost                 360
# Revenue             1876
# Gross               2338
# dtype: int64

# %%
df['Country'].isin(['France'])
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 112031    False
# 112032    False
# 112033    False
# 112034    False
# 112035    False
# Name: Country, Length: 112036, dtype: bool

# %%
df['Country'].isin(['Brazil','Germany'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 112031    False
# 112032    False
# 112033    False
# 112034    False
# 112035    False
# Name: Country, Length: 112036, dtype: bool

# %%
df['Country'].value_counts()
# Out:
# Country
# United States     38840
# Australia         23736
# Canada            14027
# United Kingdom    13486
# Germany           11027
# France            10920
# Name: count, dtype: int64

# %%
df['Country'].value_counts().sort_index()
# Out:
# Country
# Australia         23736
# Canada            14027
# France            10920
# Germany           11027
# United Kingdom    13486
# United States     38840
# Name: count, dtype: int64

# %%
df['Country'].value_counts().sort_values()
# Out:
# Country
# France            10920
# Germany           11027
# United Kingdom    13486
# Canada            14027
# Australia         23736
# United States     38840
# Name: count, dtype: int64

# %%
df['Country'].value_counts().sort_index(ascending = False)
# Out:
# Country
# United States     38840
# United Kingdom    13486
# Germany           11027
# France            10920
# Canada            14027
# Australia         23736
# Name: count, dtype: int64

# %%
pd.to_datetime(df['Date'])
# Out:
# 0        2011-01-01
# 1        2011-01-01
# 2        2011-01-01
# 3        2011-01-01
# 4        2011-01-01
#             ...
# 112031   2016-07-31
# 112032   2016-07-31
# 112033   2016-07-31
# 112034   2016-07-31
# 112035   2016-07-31
# Name: Date, Length: 112036, dtype: datetime64[ns]

# %%
df.isna().head()
# Out:
#     Date    Day  Month   Year  Customer_Age  Age_Group  Customer_Gender  \
# 0  False  False  False  False         False      False            False
# 1  False  False  False  False         False      False            False
# 2  False  False  False  False         False      False            False
# 3  False  False  False  False         False      False            False
# 4  False  False  False  False         False      False            False
#
#    Country  State  Product_Category  Sub_Category  Product  Order_Quantity  \
# 0    False  False             False         False    False           False
# 1    False  False             False         False    False           False
# 2    False  False             False         False    False           False
# 3    False  False             False         False    False           False
# 4    False  False             False         False    False           False
#
#    Unit_Cost  Unit_Price  Profit   Cost  Revenue  Gross
# ...

# %%
df.isnull().head()
# Out:
#     Date    Day  Month   Year  Customer_Age  Age_Group  Customer_Gender  \
# 0  False  False  False  False         False      False            False
# 1  False  False  False  False         False      False            False
# 2  False  False  False  False         False      False            False
# 3  False  False  False  False         False      False            False
# 4  False  False  False  False         False      False            False
#
#    Country  State  Product_Category  Sub_Category  Product  Order_Quantity  \
# 0    False  False             False         False    False           False
# 1    False  False             False         False    False           False
# 2    False  False             False         False    False           False
# 3    False  False             False         False    False           False
# 4    False  False             False         False    False           False
#
#    Unit_Cost  Unit_Price  Profit   Cost  Revenue  Gross
# ...

# %%
df.dropna()
# Out:
#              Date  Day    Month  Year  Customer_Age             Age_Group  \
# 0      2011-01-01    1  January  2011            33  Young Adults (25-34)
# 1      2011-01-01    1  January  2011            23           Youth (<25)
# 2      2011-01-01    1  January  2011            17           Youth (<25)
# 3      2011-01-01    1  January  2011            39        Adults (35-64)
# 4      2011-01-01    1  January  2011            42        Adults (35-64)
# ...           ...  ...      ...   ...           ...                   ...
# 112031 2016-07-31   31     July  2016            47        Adults (35-64)
# 112032 2016-07-31   31     July  2016            39        Adults (35-64)
# 112033 2016-07-31   31     July  2016            21           Youth (<25)
# 112034 2016-07-31   31     July  2016            31  Young Adults (25-34)
# 112035 2016-07-31   31     July  2016            34  Young Adults (25-34)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
df[df.notna()].head()
# Out:
#         Date  Day    Month  Year  Customer_Age             Age_Group  \
# 0 2011-01-01    1  January  2011            33  Young Adults (25-34)
# 1 2011-01-01    1  January  2011            23           Youth (<25)
# 2 2011-01-01    1  January  2011            17           Youth (<25)
# 3 2011-01-01    1  January  2011            39        Adults (35-64)
# 4 2011-01-01    1  January  2011            42        Adults (35-64)
#
#   Customer_Gender        Country             State Product_Category  \
# 0               F         France           Yveline            Bikes
# 1               M      Australia          Victoria            Bikes
# 2               M         Canada  British Columbia            Bikes
# 3               M  United States        Washington            Bikes
# 4               M  United States        California            Bikes
#
#      Sub_Category                 Product  Order_Quantity  Unit_Cost  \
# ...

# %%
df.dropna(how = "all").head()
# Out:
#         Date  Day    Month  Year  Customer_Age             Age_Group  \
# 0 2011-01-01    1  January  2011            33  Young Adults (25-34)
# 1 2011-01-01    1  January  2011            23           Youth (<25)
# 2 2011-01-01    1  January  2011            17           Youth (<25)
# 3 2011-01-01    1  January  2011            39        Adults (35-64)
# 4 2011-01-01    1  January  2011            42        Adults (35-64)
#
#   Customer_Gender        Country             State Product_Category  \
# 0               F         France           Yveline            Bikes
# 1               M      Australia          Victoria            Bikes
# 2               M         Canada  British Columbia            Bikes
# 3               M  United States        Washington            Bikes
# 4               M  United States        California            Bikes
#
#      Sub_Category                 Product  Order_Quantity  Unit_Cost  \
# ...

# %%
df[['Profit','Cost','Revenue','Gross']].fillna(0)
# Out:
#         Profit  Cost  Revenue  Gross
# 0         1097  4342     5439   6536
# 1          561  1252     1813   2374
# 2          900  1519     2419   3319
# 3          482  2139     2621   3103
# 4          185   344      529    714
# ...        ...   ...      ...    ...
# 112031     295   189      484    779
# 112032     230   147      377    607
# 112033      81    63      144    225
# 112034      45    19       64    109
# 112035      19    16       35     54
#
# [112036 rows x 4 columns]

# %%
df['Order_Quantity'].ffill()
# Out:
# 0          2
# 1          1
# 2          1
# 3          3
# 4          1
#           ..
# 112031    21
# 112032     7
# 112033     3
# 112034    19
# 112035     8
# Name: Order_Quantity, Length: 112036, dtype: int64

# %%
df['Profit'].fillna(df['Profit'].mean())
# Out:
# 0         1097
# 1          561
# 2          900
# 3          482
# 4          185
#           ...
# 112031     295
# 112032     230
# 112033      81
# 112034      45
# 112035      19
# Name: Profit, Length: 112036, dtype: int64

# %%
df.set_index('Date', inplace = True)

# %%
df.head(4)
# Out:
#             Day    Month  Year  Customer_Age             Age_Group  \
# Date
# 2011-01-01    1  January  2011            33  Young Adults (25-34)
# 2011-01-01    1  January  2011            23           Youth (<25)
# 2011-01-01    1  January  2011            17           Youth (<25)
# 2011-01-01    1  January  2011            39        Adults (35-64)
#
#            Customer_Gender        Country             State Product_Category  \
# Date
# 2011-01-01               F         France           Yveline            Bikes
# 2011-01-01               M      Australia          Victoria            Bikes
# 2011-01-01               M         Canada  British Columbia            Bikes
# 2011-01-01               M  United States        Washington            Bikes
#
#               Sub_Category                 Product  Order_Quantity  Unit_Cost  \
# Date
# 2011-01-01      Road Bikes        Road-150 Red, 48               2       2171
# ...

# %%
df.sort_index(inplace = True)

# %%
df.head
# Out:
# <bound method NDFrame.head of             Day    Month  Year  Customer_Age             Age_Group  \
# Date
# 2011-01-01    1  January  2011            33  Young Adults (25-34)
# 2011-01-01    1  January  2011            23           Youth (<25)
# 2011-01-01    1  January  2011            17           Youth (<25)
# 2011-01-01    1  January  2011            39        Adults (35-64)
# 2011-01-01    1  January  2011            42        Adults (35-64)
# ...         ...      ...   ...           ...                   ...
# 2016-07-31   31     July  2016            47        Adults (35-64)
# 2016-07-31   31     July  2016            39        Adults (35-64)
# 2016-07-31   31     July  2016            21           Youth (<25)
# 2016-07-31   31     July  2016            31  Young Adults (25-34)
# 2016-07-31   31     July  2016            34  Young Adults (25-34)
#
#            Customer_Gender         Country             State Product_Category  \
# Date
# ...

# %%
df['Product'].str.strip()
# Out:
# Date
# 2011-01-01           Road-150 Red, 48
# 2011-01-01     Mountain-200 Black, 46
# 2011-01-01           Road-250 Red, 44
# 2011-01-01      Road-550-W Yellow, 38
# 2011-01-01         Road-750 Black, 44
#                        ...
# 2016-07-31      Half-Finger Gloves, S
# 2016-07-31    Hydration Pack - 70 oz.
# 2016-07-31    Hydration Pack - 70 oz.
# 2016-07-31             Road Tire Tube
# 2016-07-31         Mountain Tire Tube
# Name: Product, Length: 112036, dtype: object

# %%
df['Age_Group'].str.strip()
# Out:
# Date
# 2011-01-01    Young Adults (25-34)
# 2011-01-01             Youth (<25)
# 2011-01-01             Youth (<25)
# 2011-01-01          Adults (35-64)
# 2011-01-01          Adults (35-64)
#                       ...
# 2016-07-31          Adults (35-64)
# 2016-07-31          Adults (35-64)
# 2016-07-31             Youth (<25)
# 2016-07-31    Young Adults (25-34)
# 2016-07-31    Young Adults (25-34)
# Name: Age_Group, Length: 112036, dtype: object

# %%
df.rename(columns ={'Age_Group':'Age_Category'}).head()
# Out:
#             Day    Month  Year  Customer_Age          Age_Category  \
# Date
# 2011-01-01    1  January  2011            33  Young Adults (25-34)
# 2011-01-01    1  January  2011            23           Youth (<25)
# 2011-01-01    1  January  2011            17           Youth (<25)
# 2011-01-01    1  January  2011            39        Adults (35-64)
# 2011-01-01    1  January  2011            42        Adults (35-64)
#
#            Customer_Gender        Country             State Product_Category  \
# Date
# 2011-01-01               F         France           Yveline            Bikes
# 2011-01-01               M      Australia          Victoria            Bikes
# 2011-01-01               M         Canada  British Columbia            Bikes
# 2011-01-01               M  United States        Washington            Bikes
# 2011-01-01               M  United States        California            Bikes
#
#               Sub_Category                 Product  Order_Quantity  Unit_Cost  \
# ...

# %%
df.rename(index = {'A':'B'}, inplace = True).head()

# %%
df.index.str.lower()

# %%
df.index.str.upper()

# %%
datates5 = df.columns.str.upper()
print(datates5)
# Out:
# Index(['DAY', 'MONTH', 'YEAR', 'CUSTOMER_AGE', 'AGE_GROUP', 'CUSTOMER_GENDER',
#        'COUNTRY', 'STATE', 'PRODUCT_CATEGORY', 'SUB_CATEGORY', 'PRODUCT',
#        'ORDER_QUANTITY', 'UNIT_COST', 'UNIT_PRICE', 'PROFIT', 'COST',
#        'REVENUE', 'GROSS'],
#       dtype='object')

# %%
datates6 = df.columns.str.lower()
print(datates6)
# Out:
# Index(['day', 'month', 'year', 'customer_age', 'age_group', 'customer_gender',
#        'country', 'state', 'product_category', 'sub_category', 'product',
#        'order_quantity', 'unit_cost', 'unit_price', 'profit', 'cost',
#        'revenue', 'gross'],
#       dtype='object')

# %%
df.columns.str.lower()
# Out:
# Index(['day', 'month', 'year', 'customer_age', 'age_group', 'customer_gender',
#        'country', 'state', 'product_category', 'sub_category', 'product',
#        'order_quantity', 'unit_cost', 'unit_price', 'profit', 'cost',
#        'revenue', 'gross'],
#       dtype='object')

# %%
df['Country'].str.lower()
# Out:
# Date
# 2011-01-01            france
# 2011-01-01         australia
# 2011-01-01            canada
# 2011-01-01     united states
# 2011-01-01     united states
#                    ...
# 2016-07-31    united kingdom
# 2016-07-31     united states
# 2016-07-31         australia
# 2016-07-31         australia
# 2016-07-31         australia
# Name: Country, Length: 112036, dtype: object

# %%
df['Product'].str.upper()
# Out:
# Date
# 2011-01-01           ROAD-150 RED, 48
# 2011-01-01     MOUNTAIN-200 BLACK, 46
# 2011-01-01           ROAD-250 RED, 44
# 2011-01-01      ROAD-550-W YELLOW, 38
# 2011-01-01         ROAD-750 BLACK, 44
#                        ...
# 2016-07-31      HALF-FINGER GLOVES, S
# 2016-07-31    HYDRATION PACK - 70 OZ.
# 2016-07-31    HYDRATION PACK - 70 OZ.
# 2016-07-31             ROAD TIRE TUBE
# 2016-07-31         MOUNTAIN TIRE TUBE
# Name: Product, Length: 112036, dtype: object

# %%
df['Buy_Again'] = np.random.choice([0,1], size = len(df))

# %%
df.head(5)
# Out:
#             Day    Month  Year  Customer_Age             Age_Group  \
# Date
# 2011-01-01    1  January  2011            33  Young Adults (25-34)
# 2011-01-01    1  January  2011            23           Youth (<25)
# 2011-01-01    1  January  2011            17           Youth (<25)
# 2011-01-01    1  January  2011            39        Adults (35-64)
# 2011-01-01    1  January  2011            42        Adults (35-64)
#
#            Customer_Gender        Country             State Product_Category  \
# Date
# 2011-01-01               F         France           Yveline            Bikes
# 2011-01-01               M      Australia          Victoria            Bikes
# 2011-01-01               M         Canada  British Columbia            Bikes
# 2011-01-01               M  United States        Washington            Bikes
# 2011-01-01               M  United States        California            Bikes
#
#               Sub_Category                 Product  Order_Quantity  Unit_Cost  \
# ...

# %%
df.dtypes
# Out:
# Day                  int64
# Month               object
# Year                 int64
# Customer_Age         int64
# Age_Group           object
# Customer_Gender     object
# Country             object
# State               object
# Product_Category    object
# Sub_Category        object
# Product             object
# Order_Quantity       int64
# Unit_Cost            int64
# Unit_Price           int64
# Profit               int64
# Cost                 int64
# Revenue              int64
# Gross                int64
# Buy_Again            int32
# dtype: object

# %%
df['Gross'] = df['Gross'].astype(float)

# %%
df.dtypes
# Out:
# Day                   int64
# Month                object
# Year                  int64
# Customer_Age          int64
# Age_Group            object
# Customer_Gender      object
# Country              object
# State                object
# Product_Category     object
# Sub_Category         object
# Product              object
# Order_Quantity        int64
# Unit_Cost             int64
# Unit_Price            int64
# Profit                int64
# Cost                  int64
# Revenue               int64
# Gross               float64
# Buy_Again             int32
# dtype: object

# %%
df.drop(columns = ['Month','Day'], inplace = True)

# %%
df.set_index(['Year','Date'], inplace = True)
