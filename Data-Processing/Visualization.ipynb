# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df =  pd.read_excel(r"C:\Users\Robyi\Documents\Latihan Minitab\salesdatavisualize.xlsx")

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.drop(columns=['Year','Day','Month'], inplace = True)

# %%
df.set_index('Date', inplace = True)

# %%
df.head()
# Out:
#             Customer_Age             Age_Group Customer_Gender        Country  \
# Date
# 2011-01-01            33  Young Adults (25-34)               F         France
# 2011-01-01            23           Youth (<25)               M      Australia
# 2011-01-01            17           Youth (<25)               M         Canada
# 2011-01-01            39        Adults (35-64)               M  United States
# 2011-01-01            42        Adults (35-64)               M  United States
#
#                        State Product_Category    Sub_Category  \
# Date
# 2011-01-01           Yveline            Bikes      Road Bikes
# 2011-01-01          Victoria            Bikes  Mountain Bikes
# 2011-01-01  British Columbia            Bikes      Road Bikes
# 2011-01-01        Washington            Bikes      Road Bikes
# 2011-01-01        California            Bikes      Road Bikes
#
#                            Product  Order_Quantity  Unit_Cost  Unit_Price  \
# Date
# ...

# %%
df[['Profit','Cost','Revenue']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind= 'scatter', x = 'Revenue', y = 'Unit_Cost')
# Out:
# <Axes: xlabel='Revenue', ylabel='Unit_Cost'>

# %%
df['Country'].value_counts().plot(kind='pie', autopct = '%.2f %%')
# Out:
# <Axes: ylabel='count'>

# %%
df[['Profit','Cost']].plot(kind = 'hist', figsize=(7,2))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Order_Quantity'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind= 'scatter', x = 'Customer_Gender', y = 'Unit_Cost')
# Out:
# <Axes: xlabel='Customer_Gender', ylabel='Unit_Cost'>

# %%
df.plot(kind= 'scatter', x = 'Product_Category', y = 'Cost')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Cost'>

# %%
df.plot(kind= 'box', x = 'Product', y = 'Unit_Cost')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(16,9))
sns.distplot(df['Revenue'], ax=ax)
# Out:
# C:\Users\Robyi\AppData\Local\Temp\ipykernel_10560\1260968895.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Revenue'], ax=ax)
# <Axes: xlabel='Revenue', ylabel='Density'>

# %%
ax = df['Sub_Category'].value_counts().plot(kind='bar', figsize=(14,6))
ax.set_ylabel('jumlah Kategori')
# Out:
# Text(0, 0.5, 'jumlah Kategori')

# %%
df[['Revenue','Profit','Cost']].plot(kind = 'box', vert = False)
# Out:
# <Axes: >
