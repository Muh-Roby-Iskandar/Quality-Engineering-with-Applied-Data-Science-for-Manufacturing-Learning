# %%
# Panggil library yang dibutuhkan untuk analisis data. seperti:
# 1. Pandas untuk manipulasi data tabel
# 2. Numpy untuk komputasi numerik
# 3. Seaborn dan Matplotlib untuk visualisasi data

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# fungsi read_csv merupakan fungsi dari pandas untuk membaca data tipe file CSV
# Bukan hanya tipe csv, tapi juga tipe json, parquet, excel, dan lain-lain
df = pd.read_csv(r"C:\Users\Robyi\Documents\Data Science Dataset\titanic.csv")
df.head() 

# Fungsi.head() digunakan untuk menampilkan tabel data pandas
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# fungsi "header = None" dalam membaca data adalah untuk menghilangkan judul kolom pada data tabel pandas
df = pd.read_csv(r"C:\Users\Robyi\Documents\Data Science Dataset\titanic.csv", header=None)
df.head()

# Terlihat pada tabel di bawah, bahwa dia tidak memiliki judul kolom
# Out:
#             0         1       2   \
# 0  PassengerId  Survived  Pclass
# 1            1         0       3
# 2            2         1       1
# 3            3         1       3
# 4            4         1       1
#
#                                                   3       4    5      6   \
# 0                                               Name     Sex  Age  SibSp
# 1                            Braund, Mr. Owen Harris    male   22      1
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                             Heikkinen, Miss. Laina  female   26      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
#
#       7                 8        9      10        11
# 0  Parch            Ticket     Fare  Cabin  Embarked
# 1      0         A/5 21171     7.25    NaN         S
# 2      0          PC 17599  71.2833    C85         C
# 3      0  STON/O2. 3101282    7.925    NaN         S
# 4      0            113803     53.1   C123         S

# %%
# Fungsi names digunakan untuk me-rename judul kolom yang sudah disiapkan sebelumnya
nama_kolom = ["id","selamat","kelas","nama","kelamin","umur","sib","pas","tiket","fare","kabin","embar"] # Ini nama kolom yang sudah disediakan

df = pd.read_csv(r"C:\Users\Robyi\Documents\Data Science Dataset\titanic.csv", names=nama_kolom)
df.head()

# Terlihat bahwa nama kolom sudah digantikan
# Out:
#             id   selamat   kelas  \
# 0  PassengerId  Survived  Pclass
# 1            1         0       3
# 2            2         1       1
# 3            3         1       3
# 4            4         1       1
#
#                                                 nama kelamin umur    sib  \
# 0                                               Name     Sex  Age  SibSp
# 1                            Braund, Mr. Owen Harris    male   22      1
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                             Heikkinen, Miss. Laina  female   26      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
#
#      pas             tiket     fare  kabin     embar
# 0  Parch            Ticket     Fare  Cabin  Embarked
# 1      0         A/5 21171     7.25    NaN         S
# 2      0          PC 17599  71.2833    C85         C
# 3      0  STON/O2. 3101282    7.925    NaN         S
# 4      0            113803     53.1   C123         S

# %%
# Fungsi index_col digunakan untuk menentukan index (dari kolom data yang tersedia) pada tabel data
df = pd.read_csv(r"C:\Users\Robyi\Documents\Data Science Dataset\titanic.csv", index_col='PassengerId')
df.head()

# Terlihat kolom passengerid sudah menjadi index pada tabel data di bawah
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# Fungsi index_col digunakan untuk menentukan index (dari kolom data yang tersedia) pada tabel data, bisa juga mengindex 2 kolom sekaligus
df = pd.read_csv(r"C:\Users\Robyi\Documents\Data Science Dataset\titanic.csv", index_col=['Pclass','Embarked'])
df.head(10)
# Out:
#                  PassengerId  Survived  \
# Pclass Embarked
# 3      S                   1         0
# 1      C                   2         1
# 3      S                   3         1
# 1      S                   4         1
# 3      S                   5         0
#        Q                   6         0
# 1      S                   7         0
# 3      S                   8         0
#        S                   9         1
# 2      C                  10         1
#
#                                                               Name     Sex  \
# Pclass Embarked
# 3      S                                   Braund, Mr. Owen Harris    male
# 1      C         Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3      S                                    Heikkinen, Miss. Laina  female
# 1      S              Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3      S                                  Allen, Mr. William Henry    male
# ...

# %%
# Fungsi skip row digunakan untuk tidak menampilkan row tertentu pada tabel data. 
# terlihat di bawah, kita skip row 0, 3, dan 4 sehingga row 0, 3, dan 4 tidak ditampilkan
df = pd.read_csv(r"C:\Users\Robyi\Documents\Data Science Dataset\titanic.csv", skiprows=[0,3,4])
df.head(10)
# Out:
#     1  0  3                            Braund, Mr. Owen Harris    male    22  \
# 0   2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 1   5  0  3                           Allen, Mr. William Henry    male  35.0
# 2   6  0  3                                   Moran, Mr. James    male   NaN
# 3   7  0  1                            McCarthy, Mr. Timothy J    male  54.0
# 4   8  0  3                     Palsson, Master. Gosta Leonard    male   2.0
# 5   9  1  3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 6  10  1  2                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 7  11  1  3                    Sandstrom, Miss. Marguerite Rut  female   4.0
# 8  12  1  1                           Bonnell, Miss. Elizabeth  female  58.0
# 9  13  0  3                     Saundercock, Mr. William Henry    male  20.0
#
#    1.1  0.1  A/5 21171     7.25 Unnamed: 10  S
# 0    1    0   PC 17599  71.2833         C85  C
# ...

# %%
# fungsi pd.isna() bertujuan untuk menampilkan data mana yang memiliki nilai "na" atau missing values
df = pd.read_csv(r"C:\Users\Robyi\Documents\Data Science Dataset\titanic.csv")
print(pd.isna(df))

# Nilai False berarti data tidak missing, sementara True berarti ada nilai missing
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
# Fungsi keep_default_na bertujuan untuk, agar pandas tidak menggangap cell kosong sebagai missing values
df = pd.read_csv(r"C:\Users\Robyi\Documents\Data Science Dataset\titanic.csv", keep_default_na=False)
df.head()
print(df.isna())

# Terlihat yang tadinya nilai True (yang berarti benar ada nilai missing), menjadi false karena pandas tidak menganggap nilai tersebut hilang
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
#Kita juga bisa memaksa agar suatu data dianggap NaN
missing = {"Survived":[0], "Sex":["male"]}

df = pd.read_csv(r"C:\Users\Robyi\Documents\Data Science Dataset\titanic.csv", keep_default_na=False, na_values=missing)
df.head()

# Terlihay, nilai male pada kolom sex dan nilai 0 pada kolom survived menjadi NaN
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       NaN       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       NaN       3
#
#                                                 Name     Sex Age  SibSp  \
# 0                            Braund, Mr. Owen Harris     NaN  22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38      1
# 2                             Heikkinen, Miss. Laina  female  26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35      1
# 4                           Allen, Mr. William Henry     NaN  35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500              S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250              S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500              S

# %%
# Fungsi nrows bertujuan untuk hanya menampilkan row dalam jumlah yang ingin ditentukan
df = pd.read_csv(r"C:\Users\Robyi\Documents\Data Science Dataset\titanic.csv", nrows=3)
df.head()

# Terlihat, kita hanya mengambil data sebanyak 3 rows saja
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# Fungsi sheet_name dalam membaca data excel bertujuan untuk menampilkan data di sheet tertentu
df = pd.read_excel(r"C:\Users\Robyi\Documents\Data Science Dataset\all.xlsx", sheet_name="boston")
df.head()

# Di bawah merupakan data boston dari file excel, data boston ini berada pada sheet excel ke 4 bernama boston
# Out:
#       CRIM    ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# notna() adalah kebalikan dari fungsi isna()
df.notna()

# Terlihat true berarti tidak missing, sementara false berarti data itu missing. ini kebalikan dari fungsi .isna()
# Out:
#      CRIM    ZN  INDUS  CHAS    NX    RM   AGE   DIS   RAD   TAX  PTRATIO  \
# 0    True  True   True  True  True  True  True  True  True  True     True
# 1    True  True   True  True  True  True  True  True  True  True     True
# 2    True  True   True  True  True  True  True  True  True  True     True
# 3    True  True   True  True  True  True  True  True  True  True     True
# 4    True  True   True  True  True  True  True  True  True  True     True
# ..    ...   ...    ...   ...   ...   ...   ...   ...   ...   ...      ...
# 501  True  True   True  True  True  True  True  True  True  True     True
# 502  True  True   True  True  True  True  True  True  True  True     True
# 503  True  True   True  True  True  True  True  True  True  True     True
# 504  True  True   True  True  True  True  True  True  True  True     True
# 505  True  True   True  True  True  True  True  True  True  True     True
#
#         B  LSTAT  MEDV
# 0    True   True  True
# 1    True   True  True
# ...

# %%
# fungsi .head() untuk melihat data dari atas, jikalau diisi dengan .head(6), berarti pandas menampilkan data dari atas dengan 6 row
df.head()

# .Tail() Sama dengan fungsi .head(), tapi dari bawah
df.tail(2)
# Out:
#         CRIM   ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
# Hanya menampilkan kolom NX
df['NX']

# Bisa juga dengan
df.NX
# Out:
# 0      0.538
# 1      0.469
# 2      0.469
# 3      0.458
# 4      0.458
#        ...
# 501    0.573
# 502    0.573
# 503    0.573
# 504    0.573
# 505    0.573
# Name: NX, Length: 506, dtype: float64

# %%
df = pd.read_csv(r"C:\Users\Robyi\Documents\Data Science Dataset\titanic.csv")
df.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
# Fungsi .loc[] digunakan untuk menampilkan dari keseluruhan 1 row sebuah tabel data
# Seperti contoh, loc[1] artinya menampilkan seluruh data hanya row ke-1
df.loc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
# Fungsi .iloc[:] digunakan untuk menampilkan data dari range tertentu
# Seperti contoh, .loc[2:5] artinya menampilkan seluruh data dari row 2 sampai row 4
df.iloc[2:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket    Fare Cabin Embarked
# 2  STON/O2. 3101282   7.925   NaN        S
# 3            113803  53.100  C123        S
# 4            373450   8.050   NaN        S

# %%
# Fungsi del bertujuan untuk menghapus variabel tertentu, seperti kolom pada tabel di bawah
del df['Ticket']
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Cabin Embarked
# 0      0   7.2500   NaN        S
# 1      0  71.2833   C85        C
# 2      0   7.9250   NaN        S
# 3      0  53.1000  C123        S
# 4      0   8.0500   NaN        S

# %%
# Fungsi to_numpy() bertujuan untuk mengubah format pandas menjadi numpy
df_numpy = df.to_numpy()
df_numpy
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
# Fungsi ini mengubah numpy menjadi pandas dataframe
df = pd.DataFrame(df_numpy)

# %%
df.head()
# Out:
#   0  1  2                                                  3       4     5   \
# 0  1  0  3                            Braund, Mr. Owen Harris    male  22.0
# 1  2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2  3  1  3                             Heikkinen, Miss. Laina  female  26.0
# 3  4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4  5  0  3                           Allen, Mr. William Henry    male  35.0
#
#   6  7        8     9  10
# 0  1  0     7.25   NaN  S
# 1  1  0  71.2833   C85  C
# 2  0  0    7.925   NaN  S
# 3  1  0     53.1  C123  S
# 4  0  0     8.05   NaN  S

# %%
df = pd.read_csv(r"C:\Users\Robyi\Documents\Data Science Dataset\titanic.csv")
df.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
# Fungsi untuk melihat kolom dari data
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Fungsi untuk mengganti index default ke index kolom data kita
df.index.name = 'PassengerId'
df.head()
# Out:
#              PassengerId  Survived  Pclass  \
# PassengerId
# 0                      1         0       3
# 1                      2         1       1
# 2                      3         1       3
# 3                      4         1       1
# 4                      5         0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 0                                      Braund, Mr. Owen Harris    male  22.0
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                       Heikkinen, Miss. Laina  female  26.0
# 3                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 0                1      0         A/5 21171   7.2500   NaN        S
# ...

# %%
# Salah satu fungsi analisis data dengan pandas
df.loc[[1,5,7],['Sex','Age']]
# Out:
#                 Sex   Age
# PassengerId
# 1            female  38.0
# 5              male   NaN
# 7              male   2.0

# %%
# Fungsi ini untuk menghilangkan sebuah kolom
df.drop(columns=['Sex'])
df.drop(columns=[['Sex','Age','Parch']])

# Gunakan inplace = True agar perubahan dilakukan tidak hanya sementara
df.drop(columns=['Sex'], inplace=True)
# Out:
#              PassengerId  Survived  Pclass  \
# PassengerId
# 0                      1         0       3
# 1                      2         1       1
# 2                      3         1       3
# 3                      4         1       1
# 4                      5         0       3
# ...                  ...       ...     ...
# 886                  887         0       2
# 887                  888         1       1
# 888                  889         0       3
# 889                  890         1       1
# 890                  891         0       3
#
#                                                           Name   Age  SibSp  \
# PassengerId
# 0                                      Braund, Mr. Owen Harris  22.0      1
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1
# 2                                       Heikkinen, Miss. Laina  26.0      0
# 3                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1
# ...

# %%
# Fungsi ini untuk menghilangkan sebuah row
df.drop(2)
df.drop([2,3,43,6])

# Gunakan inplace = True agar perubahan dilakukan tidak hanya sementara
df.drop(2, inplace=True)
# Out:
#              PassengerId  Survived  Pclass  \
# PassengerId
# 0                      1         0       3
# 1                      2         1       1
# 3                      4         1       1
# 4                      5         0       3
# 5                      6         0       3
# ...                  ...       ...     ...
# 886                  887         0       2
# 887                  888         1       1
# 888                  889         0       3
# 889                  890         1       1
# 890                  891         0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 0                                      Braund, Mr. Owen Harris    male  22.0
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                                     Allen, Mr. William Henry    male  35.0
# ...

# %%
# Salah satu fungsi dalam analisis data
df[df['Sex']=='male']
# Out:
#              PassengerId  Survived  Pclass                            Name  \
# PassengerId
# 0                      1         0       3         Braund, Mr. Owen Harris
# 4                      5         0       3        Allen, Mr. William Henry
# 5                      6         0       3                Moran, Mr. James
# 6                      7         0       1         McCarthy, Mr. Timothy J
# 7                      8         0       3  Palsson, Master. Gosta Leonard
# ...                  ...       ...     ...                             ...
# 883                  884         0       2   Banfield, Mr. Frederick James
# 884                  885         0       3          Sutehall, Mr. Henry Jr
# 886                  887         0       2           Montvila, Rev. Juozas
# 889                  890         1       1           Behr, Mr. Karl Howell
# 890                  891         0       3             Dooley, Mr. Patrick
#
# ...

# %%
# Salah satu fungsi dalam analisis data
df[df['Fare'] < 25 ]
# Out:
#              PassengerId  Survived  Pclass  \
# PassengerId
# 0                      1         0       3
# 2                      3         1       3
# 4                      5         0       3
# 5                      6         0       3
# 7                      8         0       3
# ...                  ...       ...     ...
# 883                  884         0       2
# 884                  885         0       3
# 886                  887         0       2
# 888                  889         0       3
# 890                  891         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# PassengerId
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# ...

# %%
# Salah satu fungsi dalam analisis data
df['Sex'] == 'female'
# Out:
# PassengerId
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
# Salah satu fungsi dalam analisis data
df['Fare'] > 25
# Out:
# PassengerId
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
# Salah satu fungsi dalam analisis data
df['Sex']
# Out:
# PassengerId
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
# Salah satu fungsi dalam analisis data
df[['Sex','Age','Fare']]
# Out:
#                 Sex   Age     Fare
# PassengerId
# 0              male  22.0   7.2500
# 1            female  38.0  71.2833
# 2            female  26.0   7.9250
# 3            female  35.0  53.1000
# 4              male  35.0   8.0500
# ...             ...   ...      ...
# 886            male  27.0  13.0000
# 887          female  19.0  30.0000
# 888          female   NaN  23.4500
# 889            male  26.0  30.0000
# 890            male  32.0   7.7500
#
# [891 rows x 3 columns]

# %%
# Salah satu fungsi dalam analisis data
df.loc[[1,6,8,15,20]]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 6             7         0       1
# 8             9         1       3
# 15           16         1       2
# 20           21         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 6       0     17463  51.8625   E46        S
# 8       2    347742  11.1333   NaN        S
# 15      0    248706  16.0000   NaN        S
# 20      0    239865  26.0000   NaN        S

# %%
# Salah satu fungsi dalam analisis data
df.loc[1,['Name','Sex']]

# Atau
df.loc[0:10,[4,5]]
# Out:
# Name    Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                female
# Name: 1, dtype: object

# %%
# Salah satu fungsi dalam analisis data
df.loc[df['Fare'] < 5 ].head(3)

# Atau
df.loc[df['Sex'] == 'male'].tail(4)

# Salah satu fungsi dalam analisis data
df[:3]
df[500:]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 179          180         0       3           Leonard, Mr. Lionel  male  36.0
# 263          264         0       1         Harrison, Mr. William  male  40.0
# 271          272         1       3  Tornquist, Mr. William Henry  male  25.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 179      0      0    LINE   0.0   NaN        S
# 263      0      0  112059   0.0   B94        S
# 271      0      0    LINE   0.0   NaN        S

# %%
# Cara buat kolom baru
df['Baru'] = df['Fare'] - 1000
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked      Baru
# 0      0         A/5 21171   7.2500   NaN        S -992.7500
# 1      0          PC 17599  71.2833   C85        C -928.7167
# 2      0  STON/O2. 3101282   7.9250   NaN        S -992.0750
# 3      0            113803  53.1000  C123        S -946.9000
# ...

# %%
# Salah satu fungsi dalam analisis data
df['Fare'] < 10
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890     True
# Name: Fare, Length: 891, dtype: bool

# %%
# Di bawah ini adalah teknik untuk mengurutkan data dari bawah
df.sort_index(ascending=False).head()

# Bisa juga mengurutkan kolom alias bukan row
df.sort_index(ascending=False, axis='columns').head()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 890          891         0       3                       Dooley, Mr. Patrick
# 889          890         1       1                     Behr, Mr. Karl Howell
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 887          888         1       1              Graham, Miss. Margaret Edith
# 886          887         0       2                     Montvila, Rev. Juozas
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked    Baru
# 890    male  32.0      0      0      370376   7.75   NaN        Q -992.25
# 889    male  26.0      0      0      111369  30.00  C148        C -970.00
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S -976.55
# 887  female  19.0      0      0      112053  30.00   B42        S -970.00
# 886    male  27.0      0      0      211536  13.00   NaN        S -987.00

# %%
# Mengurutkan nilai pada kolom tertentu dari yang terkecil
df['Fare'].sort_values()
# Bisa juga
df['Fare'].sort_values(na_position='first')

# Atau terbesar
df['Fare'].sort_values(ascending=False)

# Bisa juga untuk data non-kuantitatif
df['Name'].sort_values()
# Out:
# 258    512.3292
# 737    512.3292
# 679    512.3292
# 88     263.0000
# 27     263.0000
#          ...
# 633      0.0000
# 413      0.0000
# 822      0.0000
# 732      0.0000
# 674      0.0000
# Name: Fare, Length: 891, dtype: float64

# %%
# Untuk melihat apakah index bersifat unik
df.index.is_unique
# Out:
# True

# %%
# Untuk melihat apakah kolom sex bersifat unik, jika false berarti tidak unik
df['Sex'].is_unique
# Out:
# False

# %%
# Untuk melihat total dari sebuah kolom
df['Fare'].sum()

# Dapat dilihat bahwa total dari fare adalah 28694
# Out:
# 28693.9493

# %%
# Untuk melihat rata-rata dari sebuah kolom
df['Fare'].mean()

# Dapat dilihat bahwa rata-rata dari fare adalah 32
# Out:
# 32.204207968574636

# %%
# Salah satu teknik analisis data, melihat total dari sebuah kolom fare, tapi hanya yang berkelamin pria
df[df['Sex'] == 'male']['Fare'].sum()

# Dapat dilihat bahwa total dari fare yang berkelamin pria adalah 14727

# Bisa juga
df[df['Sex'] == 'male']['Fare'].mean()
df[df['Pclass'] == 1 ]['Fare'].median()
df[df['Pclass'] > 1 ]['Fare'].median()
df[df['Fare'] == 10 ][['Sex','Pclass']].head()
# Out:
# 14727.286500000002

# %%
# Fungsi groupby digunakan untuk melakukan pengelompokan
df.groupby('Sex')[['Pclass','Fare']].max().head()

# Terlihat di bawah bahwa kelamin pria dan wanita memiliki nilai maksimal fare yang sama yaitu 512

# Bisa juga
df.groupby('Sex')[['Pclass','Fare']].min().head()
df.groupby('Pclass')['Fare'].mean().head()
# Out:
#         Pclass      Fare
# Sex
# female       3  512.3292
# male         3  512.3292

# %%
# Fungsi untuk melihat jumlah dari data kategorik
df['Sex'].value_counts()

# Terlihat bahwa di data ini, pria ada 577, dan wanita ada 314

# bisa juga
df['Sex'].value_counts().sort_index()
df['Sex'].value_counts().sort_values(ascending=True)
df['Fare'].max()
df['Fare'].mean()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# Fungsi .describe() adalah fungsi untuk melakukan summary pada data
df.describe()

# Terlihat bahwa fare memiliki standar deviasi senilai 49,69
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare         Baru
# count  891.000000  891.000000   891.000000
# mean     0.381594   32.204208  -967.795792
# std      0.806057   49.693429    49.693429
# min      0.000000    0.000000 -1000.000000
# 25%      0.000000    7.910400  -992.089600
# 50%      0.000000   14.454200  -985.545800
# 75%      0.000000   31.000000  -969.000000
# ...

# %%
# Fungsi .idxmax() digunakan untuk mencari letak row yang memiliki nilai max
df['Fare'].idxmax()

# Terlihat bahwa kolom fare memiliki nilai max berada di row 258

# Bisa juga
df['Fare'].idxmin()
# Out:
# 258

# %%
# Fungsi ini untuk melihat ada berapa keunikan dari setiap kolom
df.nunique()

# Terlihat misalkan kolom sex hanya ada 2 karena isinya hanya male dan female
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# Baru           248
# dtype: int64

# %%
# Fungsi isin untuk mencari sebuah nilai di sebuah kolom
df['Sex'].isin(['male'])

# Terlihat bahwa row 1, dan 4 ada nilai male di kolom sex
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
# Sama seperti dropna, tapi ini untuk null
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
# ...

# %%
# Fungsi ini untuk menghilangkan data mising dari sebuah row
df.dropna()

# Bisa juga
df.dropna(how='all')

# %%
# Data missing tidak hanya bisa untuk dihilangkan, tapi juga bisa diisi
# Fungsi .ffill() untuk mengisi nilai kosong dengan akhir dari nilai sebelum nilai kosong
df['Cabin'].ffill()
df['Cabin'].bfill()

# Fungsi ini .fillna(1) berarti mengisi nilai kosong dengan nilai 1
df['Cabin'].fillna(1)

# Sementara ini, diisi dengan nilai rata-rata dari kolom tersebut
df['Cabin'].fillna(df['Cabin'].mean())

# %%
df.set_index('PassengerId', inplace=True)

# %%
# Untuk menghapus kesalahan spasi, yaitu spasi di awal dan di akhir nilai
df['Name'].str.strip()

# %%
# Untuk mengganti judul kolom
df.rename(columns ={'Sex':'Gender'}).head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name  Gender   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked      Baru
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S -992.7500
# 2                1      0          PC 17599  71.2833   C85        C -928.7167
# ...

# %%
# Untuk mengganti format data huruf, kapital atau non-kapital
df['Name'].str.lower()
df['Name'].str.upper().head()
# Out:
# PassengerId
# 1                              BRAUND, MR. OWEN HARRIS
# 2    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 3                               HEIKKINEN, MISS. LAINA
# 4         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 5                             ALLEN, MR. WILLIAM HENRY
# Name: Name, dtype: object

# %%
# Untuk melihat tipe data
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# Baru        float64
# dtype: object

# %%
# Untuk mengubah tipe data
df['Age'] = df['Age'].astype(float)

df['Pclass'].astype('category')

# %%
# Untuk drop kolom
df.drop(columns=['Parch'], inplace=True)

# %%
# Untuk melihat skor korelasi antar fitur
# Metode ini menggunakan metode Pearson's Correlation
df['Fare'].corr(df['Survived'])

# Bisa juga
df['Fare'].corr(df['Survived'], method='spearman')
df['Fare'].corr(df['Survived'], method= 'kendall')

# Terlihat bahwa korelasi antara fitur fare dan survived adalah 0,25. Sangat rendah
# Out:
# 0.2573065223849622

# %%
# Untuk melihat skor kovarian antar fitur
df['Fare'].cov(df['Survived'])

# Skor positif berarti fitur fare dan survived hubungannya searah. Artinya jika Fare naik, maka Survived cenderung naik
# Out:
# 6.22178682555896

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#       Fare Cabin Embarked      Baru
# 0   7.2500   NaN        S -992.7500
# 1  71.2833   C85        C -928.7167
# 2   7.9250   NaN        S -992.0750
# 3  53.1000  C123        S -946.9000
# 4   8.0500   NaN        S -991.9500

# %%
# Untuk melihat apakah ada duplikasi dalam data
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
# Untuk menghapus duplikat dalam data
df.drop_duplicates(inplace=True)

# %%
# Fungsi ini untuk menggantik data
df['Age'].replace([22.0, 26.0], 100).head()
df['Age'].replace([22.0, 26.0], [100,200]).head()
# Out:
# 0    100.0
# 1     38.0
# 2    100.0
# 3     35.0
# 4     35.0
# Name: Age, dtype: float64

# %%
# Untuk mencari nama atau karakter tertentu
df['Name'].str.contains('Mr.')
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 886    False
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Name, Length: 891, dtype: bool

# %%
# Fungsi di bawah ini untuk melakukan reshaping data. 
df.stack()

df.unstack()

df.transpose()

# %%
tes = df[['Sex','Pclass','Embarked']]
tes.set_index('Sex', inplace=True)
tes.head()
# Out:
#         Pclass Embarked
# Sex
# male         3        S
# female       1        C
# female       3        S
# female       1        S
# male         3        S

# %%
# Contoh hasil stacking
tes.stack()
# Out:
# Sex
# male    Pclass      3
#         Embarked    S
# female  Pclass      1
#         Embarked    C
#         Pclass      3
#                    ..
#         Embarked    S
# male    Pclass      1
#         Embarked    C
#         Pclass      3
#         Embarked    Q
# Length: 1780, dtype: object

# %%
# Mentranspose data
tes.transpose()
# Out:
# Sex      male female female female male male male male female female  ...  \
# Pclass      3      1      3      1    3    3    1    3      3      2  ...
# Embarked    S      C      S      S    S    Q    S    S      S      C  ...
#
# Sex      male female male male female male female female male male
# Pclass      3      3    2    3      3    2      1      3    1    3
# Embarked    S      S    S    S      Q    S      S      S    C    Q
#
# [2 rows x 891 columns]

# %%
# Buat datanya dulu
df1 = pd.DataFrame({
    'Name': ['Nick','John','Chris','Nick'],
    'State':['NY','NJ','NJ','NY'],
    'Test_Score':[98,99,200,85]})

df2 = pd.DataFrame({
    'Name': ['Nick','John','Chris','Nick'],
    'State':['NY','NJ','NJ','NY'],
    'Age':[21,22,21,21]})

print(df1.head())
print(df2.head())
# Out:
#     Name State  Test_Score
# 0   Nick    NY          98
# 1   John    NJ          99
# 2  Chris    NJ         200
# 3   Nick    NY          85
#     Name State  Age
# 0   Nick    NY   21
# 1   John    NJ   22
# 2  Chris    NJ   21
# 3   Nick    NY   21

# %%
# Fungsi ini untuk menggabungkan data. Tapi Nilai di dalam datanya harus sama
df3 = pd.merge(df1, df2, on =['Name','State'])
print(df3.head())
# Out:
#    Name State  Test_Score  Age
# 0  Nick    NY          98   21
# 1  Nick    NY          98   21
# 2  Nick    NY          85   21
# 3  Nick    NY          85   21
# 4  John    NJ          99   22

# %%
# Buat data baru
df4 = pd.DataFrame({'key': ['A', 'B', 'C'], 'value1': [1, 2, 3]})
df5 = pd.DataFrame({'key': ['B', 'C', 'D'], 'value2': [4, 5, 6]})

print(df4)
print(df5)
# Out:
#   key  value1
# 0   A       1
# 1   B       2
# 2   C       3
#   key  value2
# 0   B       4
# 1   C       5
# 2   D       6

# %%
# Fungsi inner pada merge melakukan penggabunan dengan cara mengeliminasi nilai jika tidak ada dalam data
df6 = pd.merge(df4, df5, on='key', how='inner')
df6.head()
# Out:
#   key  value1  value2
# 0   B       2       4
# 1   C       3       5

# %%
# Buat data baru
df7 = pd.DataFrame({'value1': [1, 2, 3]}, index=['A', 'B', 'C'])
df8 = pd.DataFrame({'value2': [4, 5, 6]}, index=['B', 'C', 'D'])

print(df7)
print(df8)
# Out:
#    value1
# A       1
# B       2
# C       3
#    value2
# B       4
# C       5
# D       6

# %%
# Fungsi join
df9 = df7.join(df8, how='inner')
df9.head()
# Out:
#    value1  value2
# B       2       4
# C       3       5

# %%
# Buat data baru
df10 = pd.DataFrame({'A': ['A0', 'A1', 'A2'], 'B': ['B0', 'B1', 'B2']})
df11 = pd.DataFrame({'A': ['A3', 'A4', 'A5'], 'B': ['B3', 'B4', 'B5']})

print(df10)
print(df11)
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
#     A   B
# 0  A3  B3
# 1  A4  B4
# 2  A5  B5

# %%
# Fungsi concat 
df12 = pd.concat([df10, df11], axis=0)
df12.head()
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 0  A3  B3
# 1  A4  B4

# %%
# Reshape data
tes = df.groupby(['Pclass','Survived'])
tes = tes['Fare']
tes.head()
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
# 5       8.4583
# 6      51.8625
# 7      21.0750
# 8      11.1333
# 9      30.0708
# 10     16.7000
# 11     26.5500
# 12      8.0500
# 15     16.0000
# 17     13.0000
# 19      7.2250
# 20     26.0000
# 21     13.0000
# 22      8.0292
# 23     35.5000
# 27    263.0000
# 30     27.7208
# 31    146.5208
# 33     10.5000
# 34     82.1708
# 35     52.0000
# 41     21.0000
# 43     41.5792
# 70     10.5000
# 72     73.5000
# Name: Fare, dtype: float64

# %%
# Fungsi agregasi berdasarkan rata-rata
tes.agg('mean')

# Bisa juga
tes.agg('max')
tes.agg('min')
tes.agg('std')
tes.agg('nedian')
# Out:
# Pclass  Survived
# 1       0           64.684007
#         1           95.608029
# 2       0           19.412328
#         1           22.055700
# 3       0           13.669364
#         1           13.694887
# Name: Fare, dtype: float64

# %%
# Fungsi tranform
tes.transform('std')
# Out:
# 0      12.118338
# 1      85.286820
# 2      10.692993
# 3      85.286820
# 4      12.118338
#          ...
# 886    15.307175
# 887    85.286820
# 888    12.118338
# 889    85.286820
# 890    12.118338
# Name: Fare, Length: 891, dtype: float64

# %%
# Describde dengan reshape
tes = df.groupby("Embarked")['Fare'].describe() 
tes
# Out:
#           count       mean        std     min       25%    50%        75%  \
# Embarked
# C         168.0  59.954144  83.912994  4.0125  13.69795  29.70  78.500025
# Q          77.0  13.276030  14.188047  6.7500   7.75000   7.75  15.500000
# S         644.0  27.079812  35.887993  0.0000   8.05000  13.00  27.900000
#
#                max
# Embarked
# C         512.3292
# Q          90.0000
# S         263.0000

# %%
# Reshape data
tes = df[['Pclass','Embarked','Fare']]
tes.head()
# Out:
#    Pclass Embarked     Fare
# 0       3        S   7.2500
# 1       1        C  71.2833
# 2       3        S   7.9250
# 3       1        S  53.1000
# 4       3        S   8.0500

# %%
# Fungsi pivot table
tes.pivot_table(index=['Pclass','Embarked']).head()
# Out:
#                        Fare
# Pclass Embarked
# 1      C         104.718529
#        Q          90.000000
#        S          70.364862
# 2      C          25.358335
#        Q          12.350000

# %%
# Reshape data
tes = df[['Pclass','Embarked','Fare','Survived']]
tes.head()
# Out:
#    Pclass Embarked     Fare  Survived
# 0       3        S   7.2500         0
# 1       1        C  71.2833         1
# 2       3        S   7.9250         1
# 3       1        S  53.1000         1
# 4       3        S   8.0500         0

# %%
# Pivot tabel
tes.pivot_table(index = ['Pclass','Embarked'], columns = 'Survived', values = 'Fare').head()
# Out:
# Survived                 0           1
# Pclass Embarked
# 1      C         78.841981  116.121754
#        Q         90.000000   90.000000
#        S         57.260926   79.750114
# 2      C         25.418225   25.305100
#        Q         12.350000   12.350000

# %%
# Ambil data deret waktu
df = pd.read_excel(r"C:\Users\Robyi\Documents\Data Science Dataset\all.xlsx", sheet_name="temperature")
df.head(4)
# Out:
#         Date  temp
# 0 1981-01-01  20.7
# 1 1981-01-02  17.9
# 2 1981-01-03  18.8
# 3 1981-01-04  14.6

# %%
# Pastikan date terbaca sebagai date di pandas
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Jadikan date sebagai index
df.set_index('Date', inplace=True)
df.head()
# Out:
#             temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
# Fungsi untuk melihat data sampai tanggal yang sudah ditentukan
df.truncate(after='1985-01-01')
# Out:
#             temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1984-12-27  12.0
# 1984-12-28  12.6
# 1984-12-29  16.0
# 1984-12-30  16.4
# 1985-01-01  13.3
#
# [1461 rows x 1 columns]

# %%
# Fungsi membuat date
pd.date_range('2000-01-01','2000-02-01')

# Bisa juga atur frekuensi
pd.date_range('2000-01-01','2000-02-01',freq='m')
pd.date_range('2000-01-01','2000-02-01',freq='y')
pd.date_range('2000-01-01','2000-02-01',freq='d')
pd.date_range('2000-01-01','2000-02-01 23:59',freq='1h')

# m untuk bulan, q untuk kuartal, y untuk tahun, d untuk hari, min untuk menit, dan h untuk jam
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10', '2000-01-11', '2000-01-12',
#                '2000-01-13', '2000-01-14', '2000-01-15', '2000-01-16',
#                '2000-01-17', '2000-01-18', '2000-01-19', '2000-01-20',
#                '2000-01-21', '2000-01-22', '2000-01-23', '2000-01-24',
#                '2000-01-25', '2000-01-26', '2000-01-27', '2000-01-28',
#                '2000-01-29', '2000-01-30', '2000-01-31', '2000-02-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Untuk membuat data date sesuai periode
pd.date_range(start="2012-04-01", periods=20)

pd.date_range(end="2012-06-01", periods=20)
pd.date_range(end="2012-06-01", periods=20, freq='m')
pd.date_range(end="2012-06-01 22:00", periods=20, freq ='1h30min')
# Out:
# DatetimeIndex(['2000-01-31'], dtype='datetime64[ns]', freq='M')

# %%
# Agregasi berdasarkan date dan fungsi statistik
df.resample('m').mean()

# Bisa juga
df.resample('y').max()
# Out:
#                  temp
# Date
# 1981-01-31  17.712903
# 1981-02-28  17.678571
# 1981-03-31  13.500000
# 1981-04-30  12.356667
# 1981-05-31   9.490323
# ...               ...
# 1990-08-31   7.825806
# 1990-09-30   9.166667
# 1990-10-31  11.345161
# 1990-11-30  12.656667
# 1990-12-31  14.367742
#
# [120 rows x 1 columns]

# %%
# Rolling digunakan untuk memajukan data
df['temp'].plot(figsize=(20,10))
df['temp'].rolling(100).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Ambil data
df = pd.read_csv(r"C:\Users\Robyi\Documents\Data Science Dataset\titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Visualiasi histogram banyak kolom
numerical = ['Age', 'Fare', 'SibSp', 'Parch']
df[numerical].hist(figsize=(12,8), bins=20)
plt.suptitle('Distribusi Variabel Numerik')
plt.tight_layout()
plt.show()

# Terlihat umur berdistribusi hampir normal, kebanyakan dari umur 20-25 tahun. tapi ada sedikit kemiringan di kiri, dan sepertinya data missing karena umurnya 0
# Fare terlihat sangat miring
# SibSp dan Parch mayoritas ada di kategori 0

# %%
# Visualisasi boxplot
plt.figure(figsize=(12,6))
sns.boxplot(data=df[numerical])
plt.title('Boxplot Variabel Numerik')
plt.show()

# Terlihat kolom fare banyak sekali outliernya (yaitu titik di luar box)

# %%
# Untuk melihat distribusi data kategorik
categorical = ['Survived', 'Pclass', 'Sex', 'Embarked']
plt.figure(figsize=(15,10))
for i, col in enumerate(categorical, 1):
    plt.subplot(2,2,i)
    sns.countplot(data=df, x=col, palette='viridis')
    plt.title(f'Distribusi {col}')
plt.tight_layout()
plt.show()

# Terlihat banyak kategori yang tidak rata
# Out:
# C:\Users\Robyi\AppData\Local\Temp\ipykernel_11840\1592978659.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='viridis')
# C:\Users\Robyi\AppData\Local\Temp\ipykernel_11840\1592978659.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='viridis')
# C:\Users\Robyi\AppData\Local\Temp\ipykernel_11840\1592978659.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='viridis')
# ...

# %%
# Untuk melihat skor korelasi
corr = df.corr(numeric_only=True, method='spearman')
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Korelasi Numerik')
plt.show()

# Terlihat Fare dan Pclass saling berlawanan korelasinya

# %%
# Untuk melihat korelasi histogram
plt.figure(figsize=(15,10))
features = ['Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked']

for i, feature in enumerate(features, 1):
    plt.subplot(2,3,i)
    sns.barplot(data=df, x=feature, y='Survived', palette='Set2')
    plt.title(f'Survival Rate by {feature}')
    plt.ylabel('Survival Rate')
plt.tight_layout()
plt.show()

# Dapat dilihat bahwa perempuan memiliki survival rate lebih tinggi dibanding pria
# Out:
# C:\Users\Robyi\AppData\Local\Temp\ipykernel_11840\1571165537.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x=feature, y='Survived', palette='Set2')
# C:\Users\Robyi\AppData\Local\Temp\ipykernel_11840\1571165537.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x=feature, y='Survived', palette='Set2')
# C:\Users\Robyi\AppData\Local\Temp\ipykernel_11840\1571165537.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x=feature, y='Survived', palette='Set2')
# ...

# %%
# Distribusi umur dengan survival
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='Age', hue='Survived', bins=30, kde=True, palette='viridis')
plt.title('Distribusi Umur vs Survival')
plt.show()

# Terlihat, orang yang berumur 20 lebih banyak tidak selamat dibanding yang selamat

# %%
# Korelasi antar kolom numerik terhadap survival
sns.pairplot(df[numerical + ['Survived']], hue='Survived', palette='viridis')
plt.suptitle('Multivariate Pairplot', y=1.02)
plt.show()

# %%
# Korelasi 3 Variabel
g = sns.FacetGrid(df, col='Survived', row='Pclass', height=3, aspect=2)
g.map(sns.histplot, 'Age', kde=True)
plt.show()

# Terlihat Pclass 3 yang tidak selamat lebih banyak, dan kebanyakan dari umur dari 20

# %%
# Persentase
df['Survived'].value_counts().plot(kind='pie', autopct = '%.2f %%')
# Out:
# <Axes: ylabel='count'>

# %%
# Untuk visualisasi 3d
from mpl_toolkits.mplot3d import Axes3D

# %%
# Ambil data
data = pd.read_csv(r"C:\Users\Robyi\Documents\Data Science Dataset\boston.csv")
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS     NX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
# Teknik visualisasi 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = data["RM"]
y = data["LSTAT"]
z = data["NX"]

ax.scatter(x, y, z, c=z, cmap='coolwarm', s=50)

ax.set_xlabel("Alcohol")
ax.set_ylabel("Malic Acid")
ax.set_zlabel("Hue")

plt.show()

# %%
# Teknik visualisasi 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

X, Y = np.meshgrid(data["RM"], data["LSTAT"])
Z = np.sin(X) + np.cos(Y)

ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_xlabel("Alcohol")
ax.set_ylabel("Malic Acid")
ax.set_zlabel("Function")

plt.show()

# %%
# Teknik visualisasi 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot(data["RM"], data["LSTAT"], data["MEDV"], marker='o')

ax.set_xlabel("Alcohol")
ax.set_ylabel("Malic Acid")
ax.set_zlabel("Hue")

plt.show()

# %%
# DATA CLEANING
data = {
    ' Name ': [' Alice  ', 'BOB', '  charlie', None, 'dave'],
    'AGE': [' 25', 'thirty', '40 ', '  19', np.nan],
    ' Salary': [' 50000.50', '60,000', ' 70000 ', 'N/A', '80000'],
    'Join Date': ['2020-01-01', '02/03/2019', 'March 5, 2018', '2017.07.12', 'NULL'],
    ' Active ': ['Yes', 'no', 'YES ', ' nO', 'y'],
}

df = pd.DataFrame(data)

# Langkah 1: Hapus spasi dari nama kolom
df.columns = df.columns.str.strip()

# Langkah 2: Bersihkan kolom teks (hapus spasi berlebihan, ubah ke format yang seragam)
df['Name'] = df['Name'].str.strip().str.title()  # Title Case

# Langkah 3: Bersihkan kolom angka (konversi ke numerik)
df['AGE'] = pd.to_numeric(df['AGE'], errors='coerce')  # 'thirty' akan menjadi NaN
df['Salary'] = df['Salary'].str.replace(',', '').str.strip()  # Hilangkan koma
df['Salary'] = pd.to_numeric(df['Salary'], errors='coerce')  # Konversi ke float

# Langkah 4: Bersihkan format tanggal
df['Join Date'] = pd.to_datetime(df['Join Date'], errors='coerce')  # Format otomatis dikenali

# Langkah 5: Normalisasi nilai boolean (Active jadi True/False)
df['Active'] = df['Active'].str.strip().str.lower().map({'yes': True, 'y': True, 'no': False, 'n': False})

# Langkah 6: Hapus duplikat jika ada
df = df.drop_duplicates()

# Langkah 7: Isi atau hapus nilai NaN jika diperlukan
df = df.fillna({'AGE': df['AGE'].median(), 'Salary': df['Salary'].mean()})  # Isi dengan median atau mean
df = df.dropna(subset=['Name'])  # Hapus jika kolom Name kosong

print("\nData Bersih:")
print(df)
