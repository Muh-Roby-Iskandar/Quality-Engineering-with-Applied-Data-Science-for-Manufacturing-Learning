# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.ml.feature import VectorAssembler, StringIndexer, StandardScaler
from pyspark.ml.classification import MultilayerPerceptronClassifier
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
import findspark
from pyspark.mllib.evaluation import MulticlassMetrics
import numpy as np
import pandas as pd
import shap

# %%
findspark.init()

# %%
spark = SparkSession.builder.appName("ClassificationMultiModels").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Robyiskandar:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.4</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>ClassificationMultiModels</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.csv(r"C:\Users\Robyi\Documents\Data Science Dataset\iris.csv", header = True, inferSchema = True)

# %%
df.show()
# Out:
# +------------+-----------+------------+-----------+-------+
# |sepal_length|sepal_width|petal_length|petal_width|species|
# +------------+-----------+------------+-----------+-------+
# |         5.1|        3.5|         1.4|        0.2| setosa|
# |         4.9|        3.0|         1.4|        0.2| setosa|
# |         4.7|        3.2|         1.3|        0.2| setosa|
# |         4.6|        3.1|         1.5|        0.2| setosa|
# |         5.0|        3.6|         1.4|        0.2| setosa|
# |         5.4|        3.9|         1.7|        0.4| setosa|
# |         4.6|        3.4|         1.4|        0.3| setosa|
# |         5.0|        3.4|         1.5|        0.2| setosa|
# |         4.4|        2.9|         1.4|        0.2| setosa|
# |         4.9|        3.1|         1.5|        0.1| setosa|
# |         5.4|        3.7|         1.5|        0.2| setosa|
# |         4.8|        3.4|         1.6|        0.2| setosa|
# |         4.8|        3.0|         1.4|        0.1| setosa|
# |         4.3|        3.0|         1.1|        0.1| setosa|
# |         5.8|        4.0|         1.2|        0.2| setosa|
# |         5.7|        4.4|         1.5|        0.4| setosa|
# |         5.4|        3.9|         1.3|        0.4| setosa|
# |         5.1|        3.5|         1.4|        0.3| setosa|
# |         5.7|        3.8|         1.7|        0.3| setosa|
# |         5.1|        3.8|         1.5|        0.3| setosa|
# +------------+-----------+------------+-----------+-------+
# only showing top 20 rows

# %%
df = df.dropDuplicates()

# %%
df = df.dropna(how="any")

# %%
assembler = VectorAssembler(inputCols=[
    "sepal_length", "sepal_width", "sepal_length", "petal_width"], 
                            outputCol="features")
df = assembler.transform(df)

# %%
Standarization = StandardScaler(inputCol="features", outputCol="features_scaled")
df = Standarization.fit(df).transform(df)

# %%
Labeler = StringIndexer(inputCol="species", outputCol="target")
df = Labeler.fit(df).transform(df)

# %%
df.show()
# Out:
# +------------+-----------+------------+-----------+----------+-----------------+--------------------+------+
# |sepal_length|sepal_width|petal_length|petal_width|   species|         features|     features_scaled|target|
# +------------+-----------+------------+-----------+----------+-----------------+--------------------+------+
# |         5.1|        3.5|         1.4|        0.3|    setosa|[5.1,3.5,5.1,0.3]|[6.15124937481215...|   2.0|
# |         5.0|        3.4|         1.6|        0.4|    setosa|[5.0,3.4,5.0,0.4]|[6.03063664197270...|   2.0|
# |         4.4|        3.2|         1.3|        0.2|    setosa|[4.4,3.2,4.4,0.2]|[5.30696024493597...|   2.0|
# |         4.8|        3.4|         1.6|        0.2|    setosa|[4.8,3.4,4.8,0.2]|[5.78941117629379...|   2.0|
# |         5.0|        3.3|         1.4|        0.2|    setosa|[5.0,3.3,5.0,0.2]|[6.03063664197270...|   2.0|
# |         6.3|        2.5|         5.0|        1.9| virginica|[6.3,2.5,6.3,1.9]|[7.59860216888560...|   1.0|
# |         4.5|        2.3|         1.3|        0.3|    setosa|[4.5,2.3,4.5,0.3]|[5.42757297777543...|   2.0|
# |         5.8|        4.0|         1.2|        0.2|    setosa|[5.8,4.0,5.8,0.2]|[6.99553850468833...|   2.0|
# |         5.8|        2.7|         3.9|        1.2|versicolor|[5.8,2.7,5.8,1.2]|[6.99553850468833...|   0.0|
# |         6.8|        3.0|         5.5|        2.1| virginica|[6.8,3.0,6.8,2.1]|[8.20166583308287...|   1.0|
# |         6.0|        2.2|         5.0|        1.5| virginica|[6.0,2.2,6.0,1.5]|[7.23676397036724...|   1.0|
# |         4.8|        3.0|         1.4|        0.3|    setosa|[4.8,3.0,4.8,0.3]|[5.78941117629379...|   2.0|
# |         5.1|        3.8|         1.6|        0.2|    setosa|[5.1,3.8,5.1,0.2]|[6.15124937481215...|   2.0|
# |         6.7|        3.0|         5.0|        1.7|versicolor|[6.7,3.0,6.7,1.7]|[8.08105310024342...|   0.0|
# |         5.1|        3.8|         1.9|        0.4|    setosa|[5.1,3.8,5.1,0.4]|[6.15124937481215...|   2.0|
# |         5.8|        2.7|         4.1|        1.0|versicolor|[5.8,2.7,5.8,1.0]|[6.99553850468833...|   0.0|
# |         6.3|        3.3|         4.7|        1.6|versicolor|[6.3,3.3,6.3,1.6]|[7.59860216888560...|   0.0|
# |         4.9|        2.4|         3.3|        1.0|versicolor|[4.9,2.4,4.9,1.0]|[5.91002390913324...|   0.0|
# |         5.7|        2.5|         5.0|        2.0| virginica|[5.7,2.5,5.7,2.0]|[6.87492577184887...|   1.0|
# |         4.9|        3.0|         1.4|        0.2|    setosa|[4.9,3.0,4.9,0.2]|[5.91002390913324...|   2.0|
# +------------+-----------+------------+-----------+----------+-----------------+--------------------+------+
# only showing top 20 rows

# %%
train, test = df.randomSplit([0.8, 0.2], seed=42)

# %%
evaluator = MulticlassClassificationEvaluator(labelCol="target", metricName="accuracy")

# %%
mlp = MultilayerPerceptronClassifier(featuresCol="features_scaled", labelCol="target")

paramGrid = ParamGridBuilder() \
    .addGrid(mlp.layers, [[4, 5, 3], [4, 10,3]]) \
    .addGrid(mlp.stepSize, [0.01, 0.1]) \
    .build()
# layer di akhir 3 karena kelas targetnya 3
# layer di awal 4 karena adaa 4 fitur
# dan hidden layer 5 dan 10

crossval = CrossValidator(estimator=mlp, estimatorParamMaps=paramGrid, evaluator=evaluator, numFolds=5)
mlp_model = crossval.fit(train)

# %%
best_model = mlp_model.bestModel
predictions = best_model.transform(test)

# %%
predictions.select("features_scaled", "target", "prediction", "probability").show(truncate=False)
# Out:
# +---------------------------------------------------------------------------+------+----------+-----------------------------------------------------------------+
# |features_scaled                                                            |target|prediction|probability                                                      |
# +---------------------------------------------------------------------------+------+----------+-----------------------------------------------------------------+
# |[5.306960244935977,6.864851782803006,5.306960244935977,0.26389603791390986]|2.0   |2.0       |[1.2470917410435777E-5,2.6814929004228116E-17,0.9999875290825896]|
# |[5.548185710614884,7.322508568323207,5.548185710614884,0.26389603791390986]|2.0   |2.0       |[6.0718926317053424E-6,6.767045148240526E-18,0.9999939281073682] |
# |[5.548185710614884,8.237822139363608,5.548185710614884,0.26389603791390986]|2.0   |2.0       |[8.790392276017615E-7,1.677816090346063E-19,0.9999991209607724]  |
# |[5.789411176293792,7.093680175563106,5.789411176293792,0.26389603791390986]|2.0   |2.0       |[1.2835963980534824E-5,2.833607988582297E-17,0.9999871640360195] |
# |[5.910023909133248,7.093680175563106,5.910023909133248,0.13194801895695493]|2.0   |2.0       |[2.8807905620506973E-6,1.6252716455792455E-18,0.999997119209438] |
# |[6.030636641972701,7.322508568323207,6.030636641972701,0.26389603791390986]|2.0   |2.0       |[1.0188701758519333E-5,1.8215445344553742E-17,0.9999898112982415]|
# |[6.030636641972701,8.237822139363608,6.030636641972701,0.26389603791390986]|2.0   |2.0       |[1.4607117667518294E-6,4.432778453545153E-19,0.9999985392882331] |
# |[6.151249374812155,8.466650532123708,6.151249374812155,0.5277920758278197] |2.0   |2.0       |[2.623154166704012E-5,1.1120989788395483E-16,0.9999737684583327] |
# |[6.513087573330518,7.780165353843407,6.513087573330518,0.5277920758278197] |2.0   |2.0       |[1.7392698073851528E-4,4.148133715531943E-15,0.9998260730192574] |
# |[6.513087573330518,7.780165353843407,6.513087573330518,0.26389603791390986]|2.0   |2.0       |[6.428894473033706E-6,7.548496824148228E-18,0.999993571105527]   |
# |[6.513087573330518,8.466650532123708,6.513087573330518,0.26389603791390986]|2.0   |2.0       |[1.5023934024293913E-6,4.677896228231429E-19,0.9999984976065975] |
# |[6.513087573330518,8.924307317643908,6.513087573330518,0.5277920758278197] |2.0   |2.0       |[1.447174530683774E-5,3.5644466078380495E-17,0.9999855282546932] |
# |[6.633700306169971,5.491881426242405,6.633700306169971,1.3194801895695492] |0.0   |0.0       |[0.9993472926712178,5.675242858908718E-5,5.959549001931648E-4]   |
# |[6.633700306169971,8.008993746603508,6.633700306169971,0.26389603791390986]|2.0   |2.0       |[4.4930757549411E-6,3.803675727144596E-18,0.999995506924245]     |
# |[6.754313039009425,6.864851782803006,6.754313039009425,1.9792202843543238] |0.0   |0.0       |[0.9846584158856274,0.015340330117719464,1.2539966529923225E-6]  |
# |[6.874925771848879,8.695478924883808,6.874925771848879,0.3958440568708647] |2.0   |2.0       |[6.823310292258977E-6,8.459200091932351E-18,0.9999931766897077]  |
# |[7.116151237527787,6.864851782803006,7.116151237527787,1.9792202843543238] |0.0   |0.0       |[0.9769854502392284,0.023013758628615637,7.911321560292146E-7]   |
# |[7.598602168885603,6.407194997282805,7.598602168885603,1.9792202843543238] |1.0   |0.0       |[0.8957112870377657,0.10428858693312887,1.2602910539119055E-7]   |
# |[7.839827634564511,6.407194997282805,7.839827634564511,1.9792202843543238] |0.0   |0.0       |[0.8668261337628732,0.13317377621505302,9.002207378588112E-8]    |
# |[7.839827634564511,7.322508568323207,7.839827634564511,2.6389603791390983] |1.0   |1.0       |[0.008142888751322552,0.9918571112481125,5.648253263770066E-13]  |
# +---------------------------------------------------------------------------+------+----------+-----------------------------------------------------------------+
# only showing top 20 rows

# %%
predictionAndLabels = predictions.select("prediction", "target").rdd.map(tuple)

# %%
predictionAndLabels = predictions.select(
    col("prediction").cast("double"),
    col("target").cast("double")
).rdd.map(tuple)

# %%
metrics = MulticlassMetrics(predictionAndLabels)
# Out:
# c:\Users\Robyi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\context.py:158: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(

# %%
accuracy = evaluator.evaluate(predictions)
print(f"Multi-Class Accuracy: {accuracy:.4f}")
# Out:
# Multi-Class Accuracy: 0.9583

# %%
print("Confusion Matrix:")
print(metrics.confusionMatrix().toArray())
# Out:
# Confusion Matrix:
# [[ 6.  0.  0.]
#  [ 1.  3.  0.]
#  [ 0.  0. 14.]]

# %%
metrics = ["accuracy", "weightedPrecision", "weightedRecall", "f1", "weightedFMeasure"]

for metric in metrics:
    evaluator = MulticlassClassificationEvaluator(
        labelCol="target", 
        predictionCol="prediction", 
        metricName=metric
    )
    score = evaluator.evaluate(predictions)
    print(f"{metric}: {score:.4f}")
# Out:
# accuracy: 0.9583
# weightedPrecision: 0.9643
# weightedRecall: 0.9583
# f1: 0.9570
# weightedFMeasure: 0.9570

# %%
predictions.crosstab("target", "prediction").show()
# Out:
# +-----------------+---+---+---+
# |target_prediction|0.0|1.0|2.0|
# +-----------------+---+---+---+
# |              1.0|  1|  3|  0|
# |              0.0|  6|  0|  0|
# |              2.0|  0|  0| 14|
# +-----------------+---+---+---+
