# %%
param_grid_lasso = {
    'alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10],  # Rentang nilai alpha
    'max_iter': [1000, 5000, 10000],  # Jumlah iterasi untuk konvergensi
    'tol': [1e-4, 1e-3, 1e-2]  # Toleransi error
}

# %%
param_grid_ridge = {
    'alpha': [0.001, 0.01, 0.1, 1, 10, 100],  # Rentang nilai alpha
    'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs'],  # Solver yang berbeda
}
